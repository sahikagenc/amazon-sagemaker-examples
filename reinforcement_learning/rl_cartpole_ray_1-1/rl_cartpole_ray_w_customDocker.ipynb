# %% [markdown]
# # Cart-pole Balancing Model with Amazon SageMaker and Ray
#
# ---
# ## Introduction
#
# In this notebook we'll start from the cart-pole balancing problem, where a pole is attached by an un-actuated joint to a cart, moving along a frictionless track. Instead of applying control theory to solve the problem, this example shows how to solve the problem with reinforcement learning on Amazon SageMaker and Ray RLlib. You can choose either TensorFlow or PyTorch as your underlying DL framework.
#
# (For a similar example using Coach library, see this [link](../rl_cartpole_coach/rl_cartpole_coach_gymEnv.ipynb). Another Cart-pole example using Coach library and offline data can be found [here](../rl_cartpole_batch_coach/rl_cartpole_batch_coach.ipynb).)
#
# 1. *Objective*: Prevent the pole from falling over
# 2. *Environment*: The environment used in this exmaple is part of OpenAI Gym, corresponding to the version of the cart-pole problem described by Barto, Sutton, and Anderson [1]
# 3. *State*: Cart position, cart velocity, pole angle, pole velocity at tip
# 4. *Action*: Push cart to the left, push cart to the right
# 5. *Reward*: Reward is 1 for every step taken, including the termination step
#
# References
#
# 1. AG Barto, RS Sutton and CW Anderson, "Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem", IEEE Transactions on Systems, Man, and Cybernetics, 1983.

# %% [markdown]
# ## Pre-requisites
#
# ### Imports
#
# To get started, we'll import the Python libraries we need, set up the environment with a few prerequisites for permissions and configurations.

# %%
import sagemaker
import boto3
import sys
import os
import glob
import re
import subprocess
import numpy as np
from IPython.display import HTML
import time
from time import gmtime, strftime
sys.path.append("common")
from misc import get_execution_role, wait_for_s3_object
from docker_utils import build_and_push_docker_image
from sagemaker.rl import RLEstimator, RLToolkit, RLFramework

# %% [markdown]
# ### Setup S3 bucket
#
# Set up the linkage and authentication to the S3 bucket that you want to use for checkpoint and the metadata.

# %%
sage_session = sagemaker.session.Session()
s3_bucket = sage_session.default_bucket()  
s3_output_path = 's3://{}/'.format(s3_bucket)
print("S3 bucket path: {}".format(s3_output_path))
# Out:
# S3 bucket path: s3://sagemaker-us-west-2-775004277940/

# %% [markdown]
# ### Define Variables
#
# We define variables such as the job prefix for the training jobs *and the image path for the container (only when this is BYOC).*

# %%
# create a descriptive job name 
job_name_prefix = 'rl-cartpole-ray'

# %% [markdown]
# ### Configure where training happens
#
# You can train your RL training jobs using the SageMaker notebook instance or local notebook instance. In both of these scenarios, you can run the following in either local or SageMaker modes. The local mode uses the SageMaker Python SDK to run your code in a local container before deploying to SageMaker. This can speed up iterative testing and debugging while using the same familiar Python SDK interface. You just need to set `local_mode = True`.

# %%
# run in local_mode on this machine, or as a SageMaker TrainingJob?
local_mode = False

if local_mode:
    instance_type = 'local'
else:
    # If on SageMaker, pick the instance type
    instance_type = "ml.c5.2xlarge"
    instance_type = "ml.p3.2xlarge"

# %% [markdown]
# ### Create an IAM role
#
# Either get the execution role when running from a SageMaker notebook instance `role = sagemaker.get_execution_role()` or, when running from local notebook instance, use utils method `role = get_execution_role()` to create an execution role.

# %%
try:
    role = sagemaker.get_execution_role()
except:
    role = get_execution_role()

print("Using IAM role arn: {}".format(role))
# Out:
# Using IAM role arn: arn:aws:iam::775004277940:role/test-distributed-rl-annal-NotebookInstanceExecutio-1WIJ7RST9BA0J

# %% [markdown]
# ### Install docker for `local` mode
#
# In order to work in `local` mode, you need to have docker installed. When running from you local machine, please make sure that you have docker and docker-compose (for local CPU machines) and nvidia-docker (for local GPU machines) installed. Alternatively, when running from a SageMaker notebook instance, you can simply run the following script to install dependenceis.
#
# Note, you can only run a single local notebook at one time.

# %%
# only run from SageMaker notebook instance
if local_mode:
    # !/bin/bash ./common/setup.sh

# %% [markdown]
# ## Write the Training Code
#
# The training code is written in the file “train-rl-cartpole-ray.py” which is uploaded in the /src directory.
# First import the environment files and the preset files, and then define the main() function.
#
# **Note**: If PyTorch is used, plese update the above training code and set `use_pytorch` to `True` in the config.

# %%
# !pygmentize src/train-rl-cartpole-ray.py
# Out:
# import json
# import os
#
# import gym
# import ray
# from ray.tune import run_experiments
# from ray.tune.registry import register_env
#
# from sagemaker_rl.ray_launcher import SageMakerRayLauncher
#
#
# def create_environment(env_config):
#     return gym.make('CartPole-v1') #, render_mode="rgb_array")
#
# class MyLauncher(SageMakerRayLauncher):
#
#     def register_env_creator(self):
#         register_env("CartPole-v1", create_environment)
#
#     def get_experiment_config(self):
#         return {
#           "training": {
#             "env": "CartPole-v1",
#             "run": "PPO",
#             "stop": {
#                 "training_iteration": 5
#             },
#             "config": {
#               "framework": "torch", # or "tf"
#               "gamma": 0.99,
#               "kl_coeff": 1.0,
#               "num_sgd_iter": 20,
#               "lr": 0.0001,
#               "sgd_minibatch_size": 1000,
#               "train_batch_size": 25000,
#               "monitor": True,  # Record videos.
#               "model": {
#                  "free_log_std": True
#               },
#               "num_workers": (self.num_cpus-1),
#               "num_gpus": self.num_gpus,
#               "batch_mode": "truncate_episodes"
#             }
#           }
#         }
#
# if __name__ == "__main__":
#     MyLauncher().train_main()

# %% [markdown]
# # Configure the framework you want to use
#
# Set `framework` to `"tf"` or `"torch"` for tensorflow or pytorch respectively.
#
# You will also have to edit your entry point i.e., [`train-sagemaker.py`](./source/train-sagemaker.py) with the configuration parameter `framework` to match the framework that you have selected.

# %%
#framework = "tf"
framework = "torch"

# %% [markdown]
# ## Build docker container
#
# We must build a custom docker container with Roboschool installed.  This takes care of everything:
#
# 1. Fetching base container image
# 2. Installing Roboschool and its dependencies
# 3. Uploading the new container image to ECR
#
# This step can take a long time if you are running on a machine with a slow internet connection.  If your notebook instance is in SageMaker or EC2 it should take 3-10 minutes depending on the instance type.

# %%
# !docker stop $(docker ps -aq)
# Out:
# "docker stop" requires at least 1 argument.
# See 'docker stop --help'.
#
# Usage:  docker stop [OPTIONS] CONTAINER [CONTAINER...]
#
# Stop one or more running containers

# %%
# !docker rm $(docker ps -aq)
# Out:
# "docker rm" requires at least 1 argument.
# See 'docker rm --help'.
#
# Usage:  docker rm [OPTIONS] CONTAINER [CONTAINER...]
#
# Remove one or more containers

# %%
# !docker rmi -f $(docker images -a -q)
# Out:
# Untagged: 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1:latest
# Untagged: 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1@sha256:b0c9b12cbc81e01e394ec53ffc49d729efd714724c6a3012fc7f17a0b2a48d39
# Untagged: ray-1_1_cartpole-gpu-torch-1.7.1:latest
# Deleted: sha256:692022756fc7ab5ecd0c9d83dd67d3c2fe391df96f629b45bf08c423cb249997
# Deleted: sha256:60d9ba77d106c50b1db5d795d4be52a7ec99f4d81aeef214eef38d88af5ab021
# Deleted: sha256:07852ed60b10e9ed91b124350044048a7f55dc847154a365d268edf9b27333a0
# Deleted: sha256:c5733ee4124c36d9fbec0f88325f41081516ddd962e9325141f5606222b4b70d
# Deleted: sha256:eec69f2bb23e0655c29358c38b4794ddfd066c90c560585c48386e54ba199d92
# Deleted: sha256:93b56c6151eca0e05150174d29fbfeb73b306aed409abafccf1d6c31f7a0805f
# Deleted: sha256:2ae10e714b0b7074c0f58f39a8272bad14994e19c1d3f2839b8ce810fa0436c4
# Deleted: sha256:accd1af2d89fe4946ab7c8765652b688b0e679c1562bcca88d1209b97bbda42e
# Deleted: sha256:0cb4f31c71b0a9200169fe24e71f126f65626e429c75d4237d483fe5387f4673
# Deleted: sha256:7d19690b706e9ae2a46f4903b70cadcd4c6ad437c47cf0e07369c5b35682386e
# Deleted: sha256:d3c31b25bfc50ca115f84086644150664dfc550cb7129a08f050e2030908e8d6
# Deleted: sha256:90cca9d5c554f4c329869c4d903d5e4d113530890c615a9ff685dcd723f952df
# Deleted: sha256:f8792024a53e0e30793eb2b33c515a6ba39a8f3be3dee80474675288aec51e6c
# Deleted: sha256:08bc94913b31822b0313eec7bb377e59555e79b1497452d9d6a98edd0ca22b7a
# Deleted: sha256:96dcee74150800ca06f2efdb9b0bc8423e26ede1326f853482b1c860b6a33332
# Deleted: sha256:33e8642cb44f96119b716badb589827e29e0ad04bebfc24d605809f5018757c6
# Deleted: sha256:15903500dc76772b23e81d1d8543aa5f94761339600cacbbd4140381613b58a8
# Deleted: sha256:38bb4d4d55657afcf42b5b993d8c3a7b61ccfd9ec04ef0086fe18dc8f0972977
# Deleted: sha256:b6206ec342f43a40b467331802f4da75ba8b2329d9190ebd874ec2661104cfd0
# Deleted: sha256:11e0fd32435325c15700376c0afd2711481002e4df8239a45d0e6b38adadc5f0
# Deleted: sha256:553fa7847c32cb0f26b0d2ac197b02ae1ff20802dd86f5855bd4a3052b3a14e8
# Deleted: sha256:7bf90efc19660d4e5ddb0e05055ca5f2598017faa0cfa767a5a14ef60166fef7
# Deleted: sha256:d375904a9463e59f55d02c6c44cb49fc1a9dbebc4aba621d0179e1452593520d
# Deleted: sha256:840833f13654f634b87ccaea0137ce520248454fc7294b7f18c99a1891b0394f
# Deleted: sha256:6f6e9b85abcb1423b06db42c49ef20b63b7cf50a304c9d83b70975c341da22c0
# Deleted: sha256:e00187bdeb285d13dd335ca5055c3eb77dbe42a2187ad03e05c7616c13744dba
# Deleted: sha256:12cc5852787d078a0c8052ea0e2e58902084b699b33b10d2b9d6f2b2b68500d0
# Deleted: sha256:8d53913b9ba1ab2b3448575184b868b89b48c2c886d1d6043089ea99bb1e9d7e
# Deleted: sha256:e0d4622e350945db3db00dcd8ddca885a2e814c9390595098d605bfd38a556dd
# Untagged: 763104351884.dkr.ecr.us-west-2.amazonaws.com/pytorch-training:1.7.1-gpu-py36-cu110-ubuntu18.04
# Untagged: 763104351884.dkr.ecr.us-west-2.amazonaws.com/pytorch-training@sha256:c19305ae3242c0ee895cbf6813df51cf1b20453551288d61eef38e0cbe30f7c9
# Deleted: sha256:e723f475a62cb11350a4e79cb468cb816dc57b262a8e7c764ab38d2a1b866a76
# Deleted: sha256:09e84ca7b478321642ac9979705d856036080f26120fd1ffa6a9bd00729d65ea
# Deleted: sha256:9bac68c3772cc15b5b3be5340ca2cbbf96feaca5cde9f22624805fa25aeb4f09
# Deleted: sha256:b9e986755d8552037f4226b5cabba63301cb4711b12117053a809e49042ea43d
# Deleted: sha256:b26c257a0c367d927545000ca2277a9dd65f3be1111b11804fd83303cd2cc4fc
# Deleted: sha256:5c37ab199ba53ec5af25eb89aefa35ad60b2861b27d16ead20eed0d1cfec9b88
# Deleted: sha256:367064b0fdce3fbaaf9f4d6651355d7d31cfa1d065fce994758012c53c8f2d42
# Deleted: sha256:ab7fe3aa44fc6dbd881719a6e64110a5845d659e7737af8c5af049eec3291d27
# Deleted: sha256:5d4903b4cae992436089069a7d07ec2b4ec793e3b675aaa3e8da788141dcd88d
# Deleted: sha256:bd7dfd92f53970f143370f1f44d0aa43f42ba33f1cd64d1296a8552b977ceb89
# Deleted: sha256:470be204c32bdec8d8951f7e4db500d88036b4720762139f573f109e0bfbae49
# Deleted: sha256:9ff98c3c20d168007684b892f0b632f73ca1c601e49285ec771ac0fe87930bcf
# Deleted: sha256:6623e7574416909921b84480caaee2ca66d7a14d05f67b0edc924e4d428d868f
# Deleted: sha256:84324f92612865be3cf4bc435b0998a05e1d7aabc8327eeea0e6aaa34bc6ac25
# Deleted: sha256:752c317d2f4cffabae425452cffcd805b24bd93d800a25ba7fce517d11dfa047
# Deleted: sha256:dae32883528f62dc246c5d3f7c933c500218e049b1bee78e8ebb56b9f337d02b
# Deleted: sha256:d37ba8e610c49eeadb4afa6d0c226c58e26b076abc0b79780849fed8e5d8d16b
# Deleted: sha256:bfbdbba4d44eeb8912a7def4e8dcda73a1881e9bae0a0ed3df4d86abf16492b8
# Deleted: sha256:4bcb5cf2082c1c98fd483e3f1238141fe01004812d0d80f2b9fcc17a57872378
# Deleted: sha256:87f5c6277d21f96ddd36988aa342c479ac3eb7e681f26eb73a9c99fceb8de9dc
# Deleted: sha256:1edb703faadfa4c67a370304c7f723f18e5395ec4ca1592f19de2e28084532eb
# Deleted: sha256:f343906043621cf5e78c7cd54fe899b3011cc6730a0359b88d2a926148fde5a1
# Deleted: sha256:672b94e5e84228f0c6c56f7266fe512dd8ea3edb3d36f1391b1d272c70ae3e47
# Deleted: sha256:d2e1c08ba24316dffa645b5d3be79aa3b0d645eb264d2dd04e843de7f71721b2
# Deleted: sha256:11bee3683db959ea5d83868b266089012e57df6e67ae7694e7901d2a16dbc87a
# Deleted: sha256:dae8a7ea43840f65647da2f7de8defbc3c80108931ad30c23e945e2b64d67087
# Deleted: sha256:2151b88be5d99cb82857dda56eee7e5a8df6d32bed5aa743320ae16754c77d83
# Deleted: sha256:01549bf5121b4d77efb1bfd467043d708999af767a093fd26c02ca3c3e4a59e8
# Deleted: sha256:5fbf9f11089e726927f69e7baffb5279ca1d1295bec8c767a02959333e919f57
# Deleted: sha256:8f04e4b268f301dce9415daa484fc23440502156d7f7a171866a76e288cd44ad
# Deleted: sha256:4147fee5217ad7ee020f2f67db420aa016eaee19ac94ce14ad34e21a3d433e5b
# Deleted: sha256:423662870fb3d051ccbc52495a1ff83e3b0c136d88614618dd18ea5b5a4fda15
# Deleted: sha256:dd44b56f7a8f4d7c34f8fe346f507e46defea98f198bccd13ef227a80a512f18
# Deleted: sha256:80580270666742c625aecc56607a806ba343a66a8f5a7fd708e6c4e4c07a3e9b
# Error: No such image: 692022756fc7
# Error: No such image: 60d9ba77d106
# Error: No such image: 07852ed60b10
# Error: No such image: c5733ee4124c
# Error: No such image: 93b56c6151ec
# Error: No such image: accd1af2d89f
# Error: No such image: 0cb4f31c71b0
# Error: No such image: 90cca9d5c554
# Error: No such image: d3c31b25bfc5
# Error: No such image: 08bc94913b31
# Error: No such image: 33e8642cb44f
# Error: No such image: 11e0fd324353
# Error: No such image: 38bb4d4d5565
# Error: No such image: b6206ec342f4
# Error: No such image: 7bf90efc1966
# Error: No such image: 840833f13654
# Error: No such image: e00187bdeb28
# Error: No such image: 8d53913b9ba1

# %%
# default as tensorflow
if framework == 'tf':
    framework_fullname = 'tensorflow'
    framework_version = "1.15.5" # TF "1.15.5" or "2.3.1" PyTorch "1.7.1"
    python_version = "py37"
elif framework == 'torch':
    framework_fullname = 'pytorch'
    framework_version = "1.7.1" # PyTorch "1.7.1"
    python_version = "py36"


aws_region = boto3.Session().region_name
suffix = python_version

# Sahika: Todo, add ml.g instances or inferon
if 'ml.p' in instance_type:
    CPU_OR_GPU = "gpu"
    if framework == "tf" and framework_version.startswith("1.15"):
        suffix += "-cu100-ubuntu18.04"
    if framework == "tf" and framework_version.startswith("2.3"):
        suffix += "-cu102-ubuntu18.04"
    if framework == "torch" and framework_version.startswith("1.7"):
        suffix += "-cu110-ubuntu18.04"
elif 'ml.c' in instance_type:
    CPU_OR_GPU = "cpu"


    
repository_short_name = "ray-1_1_cartpole-{}-{}-{}".format(CPU_OR_GPU, framework, framework_version)

docker_build_args = {
    'CPU_OR_GPU': CPU_OR_GPU, 
    'AWS_REGION': aws_region,
    'FRAMEWORK': framework_fullname,
    'VERSION': framework_version,     
    'SUFFIX': suffix
}
image_name = build_and_push_docker_image(repository_short_name, build_args=docker_build_args)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Logged into ECR
# Building docker image ray-1_1_cartpole-gpu-torch-1.7.1 from Dockerfile
# $ docker build -t ray-1_1_cartpole-gpu-torch-1.7.1 -f Dockerfile . --build-arg CPU_OR_GPU=gpu --build-arg AWS_REGION=us-west-2 --build-arg FRAMEWORK=pytorch --build-arg VERSION=1.7.1 --build-arg SUFFIX=py36-cu110-ubuntu18.04
# Sending build context to Docker daemon  606.7kB
# Step 1/24 : ARG AWS_REGION
# Step 2/24 : ARG CPU_OR_GPU
# Step 3/24 : ARG SUFFIX
# Step 4/24 : ARG VERSION
# Step 5/24 : ARG FRAMEWORK
# Step 6/24 : FROM 763104351884.dkr.ecr.${AWS_REGION}.amazonaws.com/${FRAMEWORK}-training:${VERSION}-${CPU_OR_GPU}-${SUFFIX}
# 1.7.1-gpu-py36-cu110-ubuntu18.04: Pulling from pytorch-training
# 171857c49d0f: Pulling fs layer
# 419640447d26: Pulling fs layer
# 61e52f862619: Pulling fs layer
# 2a93278deddf: Pulling fs layer
# c9f080049843: Pulling fs layer
# 8189556b2329: Pulling fs layer
# c306a0c97a55: Pulling fs layer
# 4a9478bd0b24: Pulling fs layer
# 19a76c31766d: Pulling fs layer
# 7cdef63a3bae: Pulling fs layer
# f00dcf4b415d: Pulling fs layer
# 774053844b58: Pulling fs layer
# a945309e55d8: Pulling fs layer
# 33ffae3ecd35: Pulling fs layer
# 2fdb4a2883b5: Pulling fs layer
# cf42e6c6591d: Pulling fs layer
# de844b1c6a31: Pulling fs layer
# e81677a3c816: Pulling fs layer
# ce581eeaeb8d: Pulling fs layer
# 2ea5aff114de: Pulling fs layer
# 6a2ae60641f8: Pulling fs layer
# 683c97abb8b0: Pulling fs layer
# 514a7c8a4a4e: Pulling fs layer
# 5f1f4b1e62e0: Pulling fs layer
# c15682f5d4c2: Pulling fs layer
# 1c2b7d81e2dd: Pulling fs layer
# 1ba94ea26b8a: Pulling fs layer
# f3405d5a37fd: Pulling fs layer
# ade245b57dd8: Pulling fs layer
# 8226d29bcba2: Pulling fs layer
# 95087f60a124: Pulling fs layer
# dc5fc3cb82b8: Pulling fs layer
# c5b864233c73: Pulling fs layer
# e81677a3c816: Waiting
# ce581eeaeb8d: Waiting
# 2ea5aff114de: Waiting
# 6a2ae60641f8: Waiting
# 683c97abb8b0: Waiting
# 514a7c8a4a4e: Waiting
# 5f1f4b1e62e0: Waiting
# c15682f5d4c2: Waiting
# 1c2b7d81e2dd: Waiting
# 1ba94ea26b8a: Waiting
# f3405d5a37fd: Waiting
# ade245b57dd8: Waiting
# 8226d29bcba2: Waiting
# 95087f60a124: Waiting
# dc5fc3cb82b8: Waiting
# c5b864233c73: Waiting
# 2a93278deddf: Waiting
# c9f080049843: Waiting
# 8189556b2329: Waiting
# c306a0c97a55: Waiting
# 4a9478bd0b24: Waiting
# 19a76c31766d: Waiting
# 7cdef63a3bae: Waiting
# f00dcf4b415d: Waiting
# 774053844b58: Waiting
# a945309e55d8: Waiting
# 33ffae3ecd35: Waiting
# 2fdb4a2883b5: Waiting
# cf42e6c6591d: Waiting
# de844b1c6a31: Waiting
# 61e52f862619: Verifying Checksum
# 61e52f862619: Download complete
# 419640447d26: Verifying Checksum
# 419640447d26: Download complete
# 2a93278deddf: Verifying Checksum
# 2a93278deddf: Download complete
# c9f080049843: Verifying Checksum
# c9f080049843: Download complete
# 8189556b2329: Verifying Checksum
# 8189556b2329: Download complete
# 171857c49d0f: Download complete
# 171857c49d0f: Pull complete
# 419640447d26: Pull complete
# 61e52f862619: Pull complete
# 2a93278deddf: Pull complete
# c9f080049843: Pull complete
# 8189556b2329: Pull complete
# c306a0c97a55: Verifying Checksum
# c306a0c97a55: Download complete
# 4a9478bd0b24: Verifying Checksum
# 4a9478bd0b24: Download complete
# 19a76c31766d: Verifying Checksum
# 19a76c31766d: Download complete
# 774053844b58: Verifying Checksum
# 774053844b58: Download complete
# 7cdef63a3bae: Verifying Checksum
# 7cdef63a3bae: Download complete
# 33ffae3ecd35: Verifying Checksum
# 33ffae3ecd35: Download complete
# f00dcf4b415d: Verifying Checksum
# f00dcf4b415d: Download complete
# cf42e6c6591d: Verifying Checksum
# cf42e6c6591d: Download complete
# de844b1c6a31: Download complete
# e81677a3c816: Verifying Checksum
# e81677a3c816: Download complete
# ce581eeaeb8d: Verifying Checksum
# ce581eeaeb8d: Download complete
# 2fdb4a2883b5: Verifying Checksum
# 2fdb4a2883b5: Download complete
# 6a2ae60641f8: Verifying Checksum
# 6a2ae60641f8: Download complete
# 683c97abb8b0: Verifying Checksum
# 683c97abb8b0: Download complete
# a945309e55d8: Verifying Checksum
# a945309e55d8: Download complete
# 514a7c8a4a4e: Verifying Checksum
# 514a7c8a4a4e: Download complete
# c15682f5d4c2: Verifying Checksum
# c15682f5d4c2: Download complete
# 1c2b7d81e2dd: Verifying Checksum
# 1c2b7d81e2dd: Download complete
# 1ba94ea26b8a: Verifying Checksum
# 1ba94ea26b8a: Download complete
# f3405d5a37fd: Verifying Checksum
# f3405d5a37fd: Download complete
# 5f1f4b1e62e0: Verifying Checksum
# 5f1f4b1e62e0: Download complete
# 8226d29bcba2: Verifying Checksum
# 8226d29bcba2: Download complete
# 95087f60a124: Verifying Checksum
# 95087f60a124: Download complete
# ade245b57dd8: Verifying Checksum
# ade245b57dd8: Download complete
# dc5fc3cb82b8: Verifying Checksum
# dc5fc3cb82b8: Download complete
# c5b864233c73: Verifying Checksum
# c5b864233c73: Download complete
# 2ea5aff114de: Verifying Checksum
# 2ea5aff114de: Download complete
# c306a0c97a55: Pull complete
# 4a9478bd0b24: Pull complete
# 19a76c31766d: Pull complete
# 7cdef63a3bae: Pull complete
# f00dcf4b415d: Pull complete
# 774053844b58: Pull complete
# a945309e55d8: Pull complete
# 33ffae3ecd35: Pull complete
# 2fdb4a2883b5: Pull complete
# cf42e6c6591d: Pull complete
# de844b1c6a31: Pull complete
# e81677a3c816: Pull complete
# ce581eeaeb8d: Pull complete
# 2ea5aff114de: Pull complete
# 6a2ae60641f8: Pull complete
# 683c97abb8b0: Pull complete
# 514a7c8a4a4e: Pull complete
# 5f1f4b1e62e0: Pull complete
# c15682f5d4c2: Pull complete
# 1c2b7d81e2dd: Pull complete
# 1ba94ea26b8a: Pull complete
# f3405d5a37fd: Pull complete
# ade245b57dd8: Pull complete
# 8226d29bcba2: Pull complete
# 95087f60a124: Pull complete
# dc5fc3cb82b8: Pull complete
# c5b864233c73: Pull complete
# Digest: sha256:c19305ae3242c0ee895cbf6813df51cf1b20453551288d61eef38e0cbe30f7c9
# Status: Downloaded newer image for 763104351884.dkr.ecr.us-west-2.amazonaws.com/pytorch-training:1.7.1-gpu-py36-cu110-ubuntu18.04
#  ---> e723f475a62c
# Step 7/24 : RUN apt-get update && apt-get install -y --no-install-recommends         build-essential         jq         ffmpeg         rsync         libjpeg-dev         libxrender1         python3.6-dev         python3-opengl         wget         xvfb &&     apt-get clean &&     rm -rf /var/lib/apt/lists/*
#  ---> Running in 27eb2f3f92ed
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:8 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Ign:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [577 kB]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [73.8 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1396 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1964 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [324 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1344 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2394 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [353 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2163 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.3 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [11.4 kB]
# Fetched 22.7 MB in 4s (5634 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# build-essential is already the newest version (12.4ubuntu1).
# libxrender1 is already the newest version (1:0.9.10-1).
# libxrender1 set to manually installed.
# jq is already the newest version (1.5+dfsg-2).
# wget is already the newest version (1.19.4-1ubuntu2.2).
# The following additional packages will be installed:
#   freeglut3 libapparmor1 libass9 libasyncns0 libavc1394-0 libavcodec57
#   libavdevice57 libavfilter6 libavformat57 libavresample3 libavutil55
#   libbluray2 libbs2b0 libcaca0 libcdio-cdda2 libcdio-paranoia2 libcdio17
#   libchromaprint1 libcrystalhd3 libdc1394-22 libexpat1-dev libflac8 libflite1
#   libfontenc1 libglu1-mesa libgme0 libgsm1 libiec61883-0 libjack-jackd2-0
#   libjpeg-turbo8-dev libjpeg8-dev libmp3lame0 libmpg123-0 libmysofa0 libnorm1
#   libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0
#   libpgm-5.2-0 libpopt0 libpostproc54 libpulse0 libpython3-stdlib libpython3.6
#   libpython3.6-dev libpython3.6-minimal libpython3.6-stdlib libraw1394-11
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libshine3 libslang2 libsnappy1v5
#   libsndfile1 libsndio6.1 libsodium23 libsoxr0 libspeex1 libssh-gcrypt-4
#   libswresample2 libswscale4 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau1 libvorbis0a libvorbisenc2 libvorbisfile3
#   libvpx5 libwavpack1 libwebpmux3 libx264-152 libx265-146 libxaw7
#   libxcb-shape0 libxcb-xfixes0 libxfont2 libxkbfile1 libxmu6 libxmuu1 libxss1
#   libxv1 libxvidcore4 libzmq5 libzvbi-common libzvbi0 python3 python3-minimal
#   python3.6 python3.6-minimal x11-xkb-utils xauth xserver-common
# Suggested packages:
#   ffmpeg-doc libbluray-bdj firmware-crystalhd jackd2 libportaudio2 opus-tools
#   pulseaudio libraw1394-doc sndiod speex python3-doc python3-tk python3-venv
#   python3-numpy libgle3 python3.6-venv python3.6-doc binfmt-support
# Recommended packages:
#   libaacs0 va-driver-all | va-driver vdpau-driver-all | vdpau-driver
#   xfonts-base
# The following NEW packages will be installed:
#   ffmpeg freeglut3 libapparmor1 libass9 libasyncns0 libavc1394-0 libavcodec57
#   libavdevice57 libavfilter6 libavformat57 libavresample3 libavutil55
#   libbluray2 libbs2b0 libcaca0 libcdio-cdda2 libcdio-paranoia2 libcdio17
#   libchromaprint1 libcrystalhd3 libdc1394-22 libexpat1-dev libflac8 libflite1
#   libfontenc1 libglu1-mesa libgme0 libgsm1 libiec61883-0 libjack-jackd2-0
#   libjpeg-dev libjpeg-turbo8-dev libjpeg8-dev libmp3lame0 libmpg123-0
#   libmysofa0 libnorm1 libogg0 libopenal-data libopenal1 libopenjp2-7
#   libopenmpt0 libopus0 libpgm-5.2-0 libpopt0 libpostproc54 libpulse0
#   libpython3-stdlib libpython3.6-dev libraw1394-11 librubberband2
#   libsamplerate0 libsdl2-2.0-0 libshine3 libslang2 libsnappy1v5 libsndfile1
#   libsndio6.1 libsodium23 libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2
#   libswscale4 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2
#   libva2 libvdpau1 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx5
#   libwavpack1 libwebpmux3 libx264-152 libx265-146 libxaw7 libxcb-shape0
#   libxcb-xfixes0 libxfont2 libxkbfile1 libxmu6 libxmuu1 libxss1 libxv1
#   libxvidcore4 libzmq5 libzvbi-common libzvbi0 python3 python3-minimal
#   python3-opengl python3.6 python3.6-dev python3.6-minimal rsync x11-xkb-utils
#   xauth xserver-common xvfb
# The following packages will be upgraded:
#   libpython3.6 libpython3.6-minimal libpython3.6-stdlib
# 3 upgraded, 103 newly installed, 0 to remove and 47 not upgraded.
# Need to get 85.1 MB of archives.
# After this operation, 190 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6 amd64 3.6.9-1~18.04ubuntu1.4 [1414 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-stdlib amd64 3.6.9-1~18.04ubuntu1.4 [1712 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-minimal amd64 3.6.9-1~18.04ubuntu1.4 [534 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-minimal amd64 3.6.9-1~18.04ubuntu1.4 [1610 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-minimal amd64 3.6.7-1~18.04 [23.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6 amd64 3.6.9-1~18.04ubuntu1.4 [203 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3-stdlib amd64 3.6.7-1~18.04 [7240 B]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3 amd64 3.6.7-1~18.04 [47.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxss1 amd64 1:1.2.2-1 [8582 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libapparmor1 amd64 2.12-4ubuntu5.1 [31.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpopt0 amd64 1.16-11 [26.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libslang2 amd64 2.3.1a-3ubuntu1 [424 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmuu1 amd64 2:1.1.2-2 [9674 B]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 rsync amd64 3.1.2-2.1ubuntu1.1 [334 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 xauth amd64 1:1.0.10-1 [24.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva2 amd64 2.1.0-3 [47.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-drm2 amd64 2.1.0-3 [6880 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-x11-2 amd64 2.1.0-3 [11.5 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvdpau1 amd64 1.1.1-3ubuntu1 [25.5 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavutil55 amd64 7:3.4.8-0ubuntu0.2 [190 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-12 [45.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsm1 amd64 1.0.13-4build1 [22.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmp3lame0 amd64 3.100-2 [136 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopenjp2-7 amd64 2.3.0-2build0.18.04.1 [145 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libopus0 amd64 1.1.2-1ubuntu1 [159 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libshine3 amd64 3.1.1-1 [22.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy1v5 amd64 1.1.7-1 [16.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu2 [52.1 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswresample2 amd64 7:3.4.8-0ubuntu0.2 [55.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtwolame0 amd64 0.3.13-3 [46.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbis0a amd64 1.3.5-4.2 [86.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisenc2 amd64 1.3.5-4.2 [70.7 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libvpx5 amd64 1.7.0-3ubuntu0.18.04.1 [796 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu1.5 [76.8 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebpmux3 amd64 0.6.1-2 [19.6 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx264-152 amd64 2:0.152.2854+gite9a5903-2 [609 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx265-146 amd64 2.6-3 [1026 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxvidcore4 amd64 2:1.3.5-1 [200 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi-common all 0.2.35-13 [32.1 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi0 amd64 0.2.35-13 [235 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavcodec57 amd64 7:3.4.8-0ubuntu0.2 [4595 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libavc1394-0 amd64 0.5.4-4build1 [16.1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libass9 amd64 1:0.14.0-1 [88.2 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbluray2 amd64 1:1.0.2-3 [141 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libchromaprint1 amd64 1.4.3-1 [36.8 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpg123-0 amd64 1.25.10-1 [125 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisfile3 amd64 1.3.5-4.2 [16.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpt0 amd64 0.3.6-1 [561 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssh-gcrypt-4 amd64 0.8.0~20170825.94fa1e38-1ubuntu0.7 [172 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavformat57 amd64 7:3.4.8-0ubuntu0.2 [953 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavresample3 amd64 7:3.4.8-0ubuntu0.2 [52.6 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [10.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libflite1 amd64 2.1-release-1 [12.8 MB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmysofa0 amd64 0.6~dfsg0-3+deb10u1build1 [38.5 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpostproc54 amd64 7:3.4.8-0ubuntu0.2 [50.3 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsamplerate0 amd64 0.1.9-1 [938 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/universe amd64 librubberband2 amd64 1.8.1-7ubuntu2 [86.7 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswscale4 amd64 7:3.4.8-0ubuntu0.2 [150 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnorm1 amd64 1.5r6+dfsg1-6 [224 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpgm-5.2-0 amd64 5.2.122~dfsg-2 [157 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsodium23 amd64 1.0.16-2 [143 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libzmq5 amd64 4.2.5-1ubuntu0.2 [221 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavfilter6 amd64 7:3.4.8-0ubuntu0.2 [874 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcaca0 amd64 0.99.beta19-2ubuntu0.18.04.1 [203 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio17 amd64 1.0.0-2ubuntu2 [58.8 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-2build1 [17.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-2build1 [17.2 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdc1394-22 amd64 2.2.5-1 [77.5 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 libiec61883-0 amd64 1.2.0-2 [23.5 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [263 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-data all 1:1.18.2-2 [102 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio6.1 amd64 1.1.0-3 [23.4 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal1 amd64 1:1.18.2-2 [266 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasyncns0 amd64 0.8-6 [12.1 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/main amd64 libflac8 amd64 1.3.2-1 [213 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsndfile1 amd64 1.0.28-4ubuntu0.18.04.1 [170 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse0 amd64 1:11.1-1ubuntu7.11 [266 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-2.0-0 amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [382 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shape0 amd64 1.13-2~ubuntu18.04 [5972 B]
# Get:86 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-xfixes0 amd64 1.13-2~ubuntu18.04 [9352 B]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv1 amd64 2:1.0.11-1 [10.7 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavdevice57 amd64 7:3.4.8-0ubuntu0.2 [74.9 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 ffmpeg amd64 7:3.4.8-0ubuntu0.2 [1587 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1-dev amd64 2.2.5-3ubuntu0.2 [122 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjpeg-turbo8-dev amd64 1.5.2-0ubuntu5.18.04.4 [225 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjpeg8-dev amd64 8c-2ubuntu8 [1552 B]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjpeg-dev amd64 8c-2ubuntu8 [1546 B]
# Get:96 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-dev amd64 3.6.9-1~18.04ubuntu1.4 [44.9 MB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu6 amd64 2:1.1.2-2 [46.0 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbfile1 amd64 1:1.0.9-2 [64.6 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglu1-mesa amd64 9.0.0-2.1build1 [168 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-opengl all 3.1.0+dfsg-1 [497 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-dev amd64 3.6.9-1~18.04ubuntu1.4 [508 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 x11-xkb-utils amd64 7.7+3ubuntu0.18.04.1 [160 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.8 [26.8 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.8 [784 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 85.1 MB in 11s (7674 kB/s)
# (Reading database ... 37348 files and directories currently installed.)
# Preparing to unpack .../libpython3.6_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking libpython3.6:amd64 (3.6.9-1~18.04ubuntu1.4) over (3.6.9-1~18.04ubuntu1.3) ...
# Preparing to unpack .../libpython3.6-stdlib_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# find: ‘/usr/lib/python3’: No such file or directory
# Unpacking libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.4) over (3.6.9-1~18.04ubuntu1.3) ...
# Preparing to unpack .../libpython3.6-minimal_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# find: ‘/usr/lib/python3’: No such file or directory
# Unpacking libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.4) over (3.6.9-1~18.04ubuntu1.3) ...
# Selecting previously unselected package python3.6-minimal.
# Preparing to unpack .../python3.6-minimal_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking python3.6-minimal (3.6.9-1~18.04ubuntu1.4) ...
# Setting up libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up python3.6-minimal (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package python3-minimal.
# (Reading database ... 37359 files and directories currently installed.)
# Preparing to unpack .../python3-minimal_3.6.7-1~18.04_amd64.deb ...
# Unpacking python3-minimal (3.6.7-1~18.04) ...
# Selecting previously unselected package python3.6.
# Preparing to unpack .../python3.6_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking python3.6 (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package libpython3-stdlib:amd64.
# Preparing to unpack .../libpython3-stdlib_3.6.7-1~18.04_amd64.deb ...
# Unpacking libpython3-stdlib:amd64 (3.6.7-1~18.04) ...
# Setting up python3-minimal (3.6.7-1~18.04) ...
# Selecting previously unselected package python3.
# (Reading database ... 37407 files and directories currently installed.)
# Preparing to unpack .../00-python3_3.6.7-1~18.04_amd64.deb ...
# Unpacking python3 (3.6.7-1~18.04) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../01-libogg0_1.3.2-1_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libxss1:amd64.
# Preparing to unpack .../02-libxss1_1%3a1.2.2-1_amd64.deb ...
# Unpacking libxss1:amd64 (1:1.2.2-1) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../03-libapparmor1_2.12-4ubuntu5.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.12-4ubuntu5.1) ...
# Selecting previously unselected package libpopt0:amd64.
# Preparing to unpack .../04-libpopt0_1.16-11_amd64.deb ...
# Unpacking libpopt0:amd64 (1.16-11) ...
# Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../05-libslang2_2.3.1a-3ubuntu1_amd64.deb ...
# Unpacking libslang2:amd64 (2.3.1a-3ubuntu1) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../06-libusb-1.0-0_2%3a1.0.21-2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../07-libxmuu1_2%3a1.1.2-2_amd64.deb ...
# Unpacking libxmuu1:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package rsync.
# Preparing to unpack .../08-rsync_3.1.2-2.1ubuntu1.1_amd64.deb ...
# Unpacking rsync (3.1.2-2.1ubuntu1.1) ...
# Selecting previously unselected package xauth.
# Preparing to unpack .../09-xauth_1%3a1.0.10-1_amd64.deb ...
# Unpacking xauth (1:1.0.10-1) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../10-libva2_2.1.0-3_amd64.deb ...
# Unpacking libva2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../11-libva-drm2_2.1.0-3_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../12-libva-x11-2_2.1.0-3_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../13-libvdpau1_1.1.1-3ubuntu1_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.1.1-3ubuntu1) ...
# Selecting previously unselected package libavutil55:amd64.
# Preparing to unpack .../14-libavutil55_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavutil55:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libcrystalhd3:amd64.
# Preparing to unpack .../15-libcrystalhd3_1%3a0.0~git20110715.fdd2f19-12_amd64.deb ...
# Unpacking libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../16-libgsm1_1.0.13-4build1_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.13-4build1) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../17-libmp3lame0_3.100-2_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-2) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../18-libopenjp2-7_2.3.0-2build0.18.04.1_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.3.0-2build0.18.04.1) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../19-libopus0_1.1.2-1ubuntu1_amd64.deb ...
# Unpacking libopus0:amd64 (1.1.2-1ubuntu1) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../20-libshine3_3.1.1-1_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-1) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../21-libsnappy1v5_1.1.7-1_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.7-1) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../22-libspeex1_1.2~rc1.2-1ubuntu2_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1ubuntu2) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../23-libsoxr0_0.1.2-3_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.2-3) ...
# Selecting previously unselected package libswresample2:amd64.
# Preparing to unpack .../24-libswresample2_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libswresample2:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../25-libtheora0_1.1.1+dfsg.1-14_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../26-libtwolame0_0.3.13-3_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.3.13-3) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../27-libvorbis0a_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../28-libvorbisenc2_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../29-libvpx5_1.7.0-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../30-libwavpack1_5.1.0-2ubuntu1.5_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.1.0-2ubuntu1.5) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../31-libwebpmux3_0.6.1-2_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2) ...
# Selecting previously unselected package libx264-152:amd64.
# Preparing to unpack .../32-libx264-152_2%3a0.152.2854+gite9a5903-2_amd64.deb ...
# Unpacking libx264-152:amd64 (2:0.152.2854+gite9a5903-2) ...
# Selecting previously unselected package libx265-146:amd64.
# Preparing to unpack .../33-libx265-146_2.6-3_amd64.deb ...
# Unpacking libx265-146:amd64 (2.6-3) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../34-libxvidcore4_2%3a1.3.5-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.5-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../35-libzvbi-common_0.2.35-13_all.deb ...
# Unpacking libzvbi-common (0.2.35-13) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../36-libzvbi0_0.2.35-13_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-13) ...
# Selecting previously unselected package libavcodec57:amd64.
# Preparing to unpack .../37-libavcodec57_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavcodec57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../38-libraw1394-11_2.1.2-1_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-1) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../39-libavc1394-0_0.5.4-4build1_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-4build1) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../40-libass9_1%3a0.14.0-1_amd64.deb ...
# Unpacking libass9:amd64 (1:0.14.0-1) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../41-libbluray2_1%3a1.0.2-3_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.0.2-3) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../42-libchromaprint1_1.4.3-1_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.4.3-1) ...
# Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../43-libgme0_0.6.2-1_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.2-1) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../44-libmpg123-0_1.25.10-1_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.25.10-1) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../45-libvorbisfile3_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../46-libopenmpt0_0.3.6-1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.3.6-1) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../47-libssh-gcrypt-4_0.8.0~20170825.94fa1e38-1ubuntu0.7_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.8.0~20170825.94fa1e38-1ubuntu0.7) ...
# Selecting previously unselected package libavformat57:amd64.
# Preparing to unpack .../48-libavformat57_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavformat57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libavresample3:amd64.
# Preparing to unpack .../49-libavresample3_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavresample3:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../50-libbs2b0_3.1.0+dfsg-2.2_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../51-libflite1_2.1-release-1_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-1) ...
# Selecting previously unselected package libmysofa0:amd64.
# Preparing to unpack .../52-libmysofa0_0.6~dfsg0-3+deb10u1build1_amd64.deb ...
# Unpacking libmysofa0:amd64 (0.6~dfsg0-3+deb10u1build1) ...
# Selecting previously unselected package libpostproc54:amd64.
# Preparing to unpack .../53-libpostproc54_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libpostproc54:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../54-libsamplerate0_0.1.9-1_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.1.9-1) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../55-librubberband2_1.8.1-7ubuntu2_amd64.deb ...
# Unpacking librubberband2:amd64 (1.8.1-7ubuntu2) ...
# Selecting previously unselected package libswscale4:amd64.
# Preparing to unpack .../56-libswscale4_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libswscale4:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../57-libnorm1_1.5r6+dfsg1-6_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5r6+dfsg1-6) ...
# Selecting previously unselected package libpgm-5.2-0:amd64.
# Preparing to unpack .../58-libpgm-5.2-0_5.2.122~dfsg-2_amd64.deb ...
# Unpacking libpgm-5.2-0:amd64 (5.2.122~dfsg-2) ...
# Selecting previously unselected package libsodium23:amd64.
# Preparing to unpack .../59-libsodium23_1.0.16-2_amd64.deb ...
# Unpacking libsodium23:amd64 (1.0.16-2) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../60-libzmq5_4.2.5-1ubuntu0.2_amd64.deb ...
# Unpacking libzmq5:amd64 (4.2.5-1ubuntu0.2) ...
# Selecting previously unselected package libavfilter6:amd64.
# Preparing to unpack .../61-libavfilter6_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavfilter6:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../62-libcaca0_0.99.beta19-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.1) ...
# Selecting previously unselected package libcdio17:amd64.
# Preparing to unpack .../63-libcdio17_1.0.0-2ubuntu2_amd64.deb ...
# Unpacking libcdio17:amd64 (1.0.0-2ubuntu2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../64-libcdio-cdda2_10.2+0.94+2-2build1_amd64.deb ...
# Unpacking libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../65-libcdio-paranoia2_10.2+0.94+2-2build1_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# Selecting previously unselected package libdc1394-22:amd64.
# Preparing to unpack .../66-libdc1394-22_2.2.5-1_amd64.deb ...
# Unpacking libdc1394-22:amd64 (2.2.5-1) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../67-libiec61883-0_1.2.0-2_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-2) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../68-libjack-jackd2-0_1.9.12~dfsg-2_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../69-libopenal-data_1%3a1.18.2-2_all.deb ...
# Unpacking libopenal-data (1:1.18.2-2) ...
# Selecting previously unselected package libsndio6.1:amd64.
# Preparing to unpack .../70-libsndio6.1_1.1.0-3_amd64.deb ...
# Unpacking libsndio6.1:amd64 (1.1.0-3) ...
# Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../71-libopenal1_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.18.2-2) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../72-libasyncns0_0.8-6_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../73-libflac8_1.3.2-1_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.2-1) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../74-libsndfile1_1.0.28-4ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-4ubuntu0.18.04.1) ...
# Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../75-libpulse0_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse0:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../76-libsdl2-2.0-0_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package libxcb-shape0:amd64.
# Preparing to unpack .../77-libxcb-shape0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shape0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../78-libxcb-xfixes0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../79-libxv1_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv1:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libavdevice57:amd64.
# Preparing to unpack .../80-libavdevice57_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavdevice57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../81-ffmpeg_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking ffmpeg (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../82-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package libexpat1-dev:amd64.
# Preparing to unpack .../83-libexpat1-dev_2.2.5-3ubuntu0.2_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.5-3ubuntu0.2) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../84-libfontenc1_1%3a1.1.3-1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.3-1) ...
# Selecting previously unselected package libjpeg-turbo8-dev:amd64.
# Preparing to unpack .../85-libjpeg-turbo8-dev_1.5.2-0ubuntu5.18.04.4_amd64.deb ...
# Unpacking libjpeg-turbo8-dev:amd64 (1.5.2-0ubuntu5.18.04.4) ...
# Selecting previously unselected package libjpeg8-dev:amd64.
# Preparing to unpack .../86-libjpeg8-dev_8c-2ubuntu8_amd64.deb ...
# Unpacking libjpeg8-dev:amd64 (8c-2ubuntu8) ...
# Selecting previously unselected package libjpeg-dev:amd64.
# Preparing to unpack .../87-libjpeg-dev_8c-2ubuntu8_amd64.deb ...
# Unpacking libjpeg-dev:amd64 (8c-2ubuntu8) ...
# Selecting previously unselected package libpython3.6-dev:amd64.
# Preparing to unpack .../88-libpython3.6-dev_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking libpython3.6-dev:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../89-libxmu6_2%3a1.1.2-2_amd64.deb ...
# Unpacking libxmu6:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../90-libxaw7_2%3a1.0.13-1_amd64.deb ...
# Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../91-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../92-libxkbfile1_1%3a1.0.9-2_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.0.9-2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../93-libglu1-mesa_9.0.0-2.1build1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../94-python3-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package python3.6-dev.
# Preparing to unpack .../95-python3.6-dev_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking python3.6-dev (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../96-x11-xkb-utils_7.7+3ubuntu0.18.04.1_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../97-xserver-common_2%3a1.19.6-1ubuntu4.8_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../98-xvfb_2%3a1.19.6-1ubuntu4.8_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.8) ...
# Setting up libxkbfile1:amd64 (1:1.0.9-2) ...
# Setting up libpgm-5.2-0:amd64 (5.2.122~dfsg-2) ...
# Setting up libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpopt0:amd64 (1.16-11) ...
# Setting up libtwolame0:amd64 (0.3.13-3) ...
# Setting up libraw1394-11:amd64 (2.1.2-1) ...
# Setting up libx264-152:amd64 (2:0.152.2854+gite9a5903-2) ...
# Setting up libxcb-xfixes0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libopenjp2-7:amd64 (2.3.0-2build0.18.04.1) ...
# Setting up python3.6 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up libasyncns0:amd64 (0.8-6) ...
# Setting up libwavpack1:amd64 (5.1.0-2ubuntu1.5) ...
# Setting up libflite1:amd64 (2.1-release-1) ...
# Setting up libsoxr0:amd64 (0.1.2-3) ...
# Setting up libssh-gcrypt-4:amd64 (0.8.0~20170825.94fa1e38-1ubuntu0.7) ...
# Setting up libxss1:amd64 (1:1.2.2-1) ...
# Setting up libass9:amd64 (1:0.14.0-1) ...
# Setting up libbluray2:amd64 (1:1.0.2-3) ...
# Setting up libvdpau1:amd64 (1.1.1-3ubuntu1) ...
# Setting up libshine3:amd64 (3.1.1-1) ...
# Setting up libva2:amd64 (2.1.0-3) ...
# Setting up libiec61883-0:amd64 (1.2.0-2) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1ubuntu2) ...
# Setting up libxvidcore4:amd64 (2:1.3.5-1) ...
# Setting up libxmuu1:amd64 (2:1.1.2-2) ...
# Setting up libopus0:amd64 (1.1.2-1ubuntu1) ...
# Setting up libxmu6:amd64 (2:1.1.2-2) ...
# Setting up libx265-146:amd64 (2.6-3) ...
# Setting up libopenal-data (1:1.18.2-2) ...
# Setting up rsync (3.1.2-2.1ubuntu1.1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# Setting up xauth (1:1.0.10-1) ...
# Setting up libnorm1:amd64 (1.5r6+dfsg1-6) ...
# Setting up libogg0:amd64 (1.3.2-1) ...
# Setting up libsodium23:amd64 (1.0.16-2) ...
# Setting up libmp3lame0:amd64 (3.100-2) ...
# Setting up libjpeg-turbo8-dev:amd64 (1.5.2-0ubuntu5.18.04.4) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Setting up libjpeg8-dev:amd64 (8c-2ubuntu8) ...
# Setting up libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# Setting up libjpeg-dev:amd64 (8c-2ubuntu8) ...
# Setting up libapparmor1:amd64 (2.12-4ubuntu5.1) ...
# Setting up libwebpmux3:amd64 (0.6.1-2) ...
# Setting up libsnappy1v5:amd64 (1.1.7-1) ...
# Setting up libva-drm2:amd64 (2.1.0-3) ...
# Setting up libavc1394-0:amd64 (0.5.4-4build1) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# Setting up libzvbi-common (0.2.35-13) ...
# Setting up libexpat1-dev:amd64 (2.2.5-3ubuntu0.2) ...
# Setting up libxcb-shape0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Setting up libvpx5:amd64 (1.7.0-3ubuntu0.18.04.1) ...
# Setting up libgme0:amd64 (0.6.2-1) ...
# Setting up libzvbi0:amd64 (0.2.35-13) ...
# Setting up libva-x11-2:amd64 (2.1.0-3) ...
# Setting up libsamplerate0:amd64 (0.1.9-1) ...
# Setting up libsndio6.1:amd64 (1.1.0-3) ...
# Setting up libvorbis0a:amd64 (1.3.5-4.2) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libmpg123-0:amd64 (1.25.10-1) ...
# Setting up libslang2:amd64 (2.3.1a-3ubuntu1) ...
# Setting up libgsm1:amd64 (1.0.13-4build1) ...
# Setting up libmysofa0:amd64 (0.6~dfsg0-3+deb10u1build1) ...
# Setting up libcdio17:amd64 (1.0.0-2ubuntu2) ...
# Setting up libpython3.6:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4.2) ...
# Setting up libxaw7:amd64 (2:1.0.13-1) ...
# Setting up libpython3-stdlib:amd64 (3.6.7-1~18.04) ...
# Setting up libzmq5:amd64 (4.2.5-1ubuntu0.2) ...
# Setting up libavutil55:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up python3 (3.6.7-1~18.04) ...
# running python rtupdate hooks for python3.6...
# running python post-rtupdate hooks for python3.6...
# Setting up x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Setting up libopenmpt0:amd64 (0.3.6-1) ...
# Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# Setting up python3-opengl (3.1.0+dfsg-1) ...
# Setting up libswresample2:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libpython3.6-dev:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up librubberband2:amd64 (1.8.1-7ubuntu2) ...
# Setting up libswscale4:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# Setting up libpostproc54:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Setting up libopenal1:amd64 (1:1.18.2-2) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4.2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.1) ...
# Setting up python3.6-dev (3.6.9-1~18.04ubuntu1.4) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.8) ...
# Setting up libavresample3:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.8) ...
# Setting up libavcodec57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libsndfile1:amd64 (1.0.28-4ubuntu0.18.04.1) ...
# Setting up libchromaprint1:amd64 (1.4.3-1) ...
# Setting up libpulse0:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up libavformat57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libavfilter6:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libavdevice57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up ffmpeg (7:3.4.8-0ubuntu0.2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Removing intermediate container 27eb2f3f92ed
#  ---> 8c78bd57adfa
# Step 8/24 : RUN pip install --upgrade pip
#  ---> Running in 167997ac57e9
# ...
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (1.15.0)
# Requirement already satisfied: pip in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (21.0.1)
# Collecting flask==1.1.1
#   Downloading Flask-1.1.1-py2.py3-none-any.whl (94 kB)
# Collecting gunicorn
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (1.3.3)
# Requirement already satisfied: gevent in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (21.1.2)
# Requirement already satisfied: inotify_simple==1.2.1 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (1.2.1)
# Requirement already satisfied: werkzeug>=0.15.5 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (1.0.1)
# Requirement already satisfied: paramiko>=2.4.2 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (2.7.2)
# Requirement already satisfied: psutil>=5.6.7 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (5.8.0)
# Requirement already satisfied: protobuf>=3.1 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (3.15.1)
# Requirement already satisfied: scipy>=1.2.2 in /opt/conda/lib/python3.6/site-packages (from sagemaker-containers) (1.5.4)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: click>=5.1 in /opt/conda/lib/python3.6/site-packages (from flask==1.1.1->sagemaker-containers) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/lib/python3.6/site-packages (from flask==1.1.1->sagemaker-containers) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from Jinja2>=2.10.1->flask==1.1.1->sagemaker-containers) (1.1.1)
# Requirement already satisfied: pynacl>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from paramiko>=2.4.2->sagemaker-containers) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.6/site-packages (from paramiko>=2.4.2->sagemaker-containers) (3.4.6)
# Requirement already satisfied: bcrypt>=3.1.3 in /opt/conda/lib/python3.6/site-packages (from paramiko>=2.4.2->sagemaker-containers) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /opt/conda/lib/python3.6/site-packages (from bcrypt>=3.1.3->paramiko>=2.4.2->sagemaker-containers) (1.14.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4.2->sagemaker-containers) (2.20)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from boto3->sagemaker-containers) (0.3.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3->sagemaker-containers) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.13 in /opt/conda/lib/python3.6/site-packages (from boto3->sagemaker-containers) (1.20.13)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.13->boto3->sagemaker-containers) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.13->boto3->sagemaker-containers) (2.8.1)
# Requirement already satisfied: greenlet<2.0,>=0.4.17 in /opt/conda/lib/python3.6/site-packages (from gevent->sagemaker-containers) (1.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from gevent->sagemaker-containers) (49.6.0.post20210108)
# Requirement already satisfied: zope.interface in /opt/conda/lib/python3.6/site-packages (from gevent->sagemaker-containers) (5.2.0)
# Requirement already satisfied: zope.event in /opt/conda/lib/python3.6/site-packages (from gevent->sagemaker-containers) (4.5.0)
# Building wheels for collected packages: sagemaker-containers, typing
#   Building wheel for sagemaker-containers (setup.py): started
#   Building wheel for sagemaker-containers (setup.py): finished with status 'done'
#   Created wheel for sagemaker-containers: filename=sagemaker_containers-2.8.6.post2-cp36-cp36m-linux_x86_64.whl size=82651 sha256=54350259266d61da7e004df928b45d220b3a6c131bbd8c071aa391fb76586f94
#   Stored in directory: /root/.cache/pip/wheels/68/04/ea/55bcff411d9f6eb0a064d2b1997dfd733640d8659ff2c98dbe
#   Building wheel for typing (setup.py): started
#   Building wheel for typing (setup.py): finished with status 'done'
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26308 sha256=d31f209741eb3b4c2f34294aa0ccaef98e37ba8073b638a9cfe48a1c023c4bca
#   Stored in directory: /root/.cache/pip/wheels/5f/63/c2/b85489bbea28cb5d36cfe197244f898428004fa3caa7a23116
# Successfully built sagemaker-containers typing
# Installing collected packages: itsdangerous, typing, gunicorn, flask, sagemaker-containers
# Successfully installed flask-1.1.1 gunicorn-20.0.4 itsdangerous-1.1.0 sagemaker-containers-2.8.6.post2 typing-3.7.4.3
# Removing intermediate container e53257efb07c
#  ---> df480a42dc23
# Step 19/24 : ENV PYTHONUNBUFFERED 1
#  ---> Running in 669996e19abe
# Removing intermediate container 669996e19abe
#  ---> 1d57227fa359
# Step 20/24 : RUN python -c "import gym;import sagemaker_containers.cli.train;import ray; from sagemaker_containers.cli.train import main"
#  ---> Running in d7527a2fc176
# Removing intermediate container d7527a2fc176
#  ---> d5924a58493b
# Step 21/24 : WORKDIR /opt/ml/code
#  ---> Running in 96199dbd2af8
# Removing intermediate container 96199dbd2af8
#  ---> b940885e88ab
# Step 22/24 : RUN pip freeze
#  ---> Running in 89163044f4f9
# absl-py==0.12.0
# aiohttp==3.7.4.post0
# aiohttp-cors==0.7.0
# aioredis==1.3.1
# apex==0.1
# async-timeout==3.0.1
# atari-py==0.2.6
# attrs==20.3.0
# aws-parallelcluster==2.10.1
# awscli==1.19.13
# backcall==0.2.0
# bcrypt==3.2.0
# beautifulsoup4==4.9.3
# blessings==1.7
# blis==0.7.4
# boto3==1.17.13
# botocore==1.20.13
# Bottleneck==1.3.2
# brotlipy==0.7.0
# cachetools==4.2.1
# catalogue==2.0.1
# certifi==2020.12.5
# cffi @ file:///home/conda/feedstock_root/build_artifacts/cffi_1613413856675/work
# chardet @ file:///home/conda/feedstock_root/build_artifacts/chardet_1602255305250/work
# click==7.1.2
# cloudpickle==1.6.0
# cmake==3.18.2.post1
# colorama==0.4.3
# colorful==0.5.4
# conda==4.9.2
# conda-package-handling @ file:///home/conda/feedstock_root/build_artifacts/conda-package-handling_1602876788498/work
# contextvars==2.4
# cryptography==3.4.6
# cycler==0.10.0
# cymem==2.0.5
# Cython @ file:///tmp/build/80754af9/cython_1594831565616/work
# dataclasses==0.8
# decorator==4.4.2
# dgl-cu110==0.6a210222
# dill==0.3.3
# dm-tree==0.1.5
# docutils==0.15.2
# fastai==1.0.61
# fastprogress==1.0.0
# filelock==3.0.12
# Flask==1.1.1
# fsspec==0.8.5
# future==0.18.2
# gast==0.4.0
# gevent==21.1.2
# google-api-core==1.26.1
# google-auth==1.27.1
# google-pasta==0.2.0
# googleapis-common-protos==1.53.0
# gpustat==0.6.0
# GPUtil==1.4.0
# greenlet==1.0.0
# grpcio==1.36.1
# gunicorn==20.0.4
# gym==0.18.0
# h5py==2.8.0
# hiredis==1.1.0
# horovod==0.20.3
# idna @ file:///tmp/build/80754af9/idna_1593446292537/work
# idna-ssl==1.1.0
# immutables==0.15
# importlib-metadata==3.4.0
# inotify-simple==1.2.1
# ipaddress==1.0.23
# ipython @ file:///tmp/build/80754af9/ipython_1593447367857/work
# ipython-genutils==0.2.0
# itsdangerous==1.1.0
# jedi @ file:///tmp/build/80754af9/jedi_1611333750012/work
# Jinja2==2.11.3
# jmespath==0.10.0
# joblib @ file:///tmp/build/80754af9/joblib_1613502643832/work
# jsonpatch==1.28
# jsonpointer==2.0
# jsonschema==3.2.0
# kiwisolver==1.3.1
# lz4==3.1.3
# MarkupSafe==1.1.1
# matplotlib==3.3.4
# mpi4py==3.0.3
# msgpack==1.0.2
# multidict==5.1.0
# murmurhash==1.0.5
# networkx==2.5
# numexpr==2.7.2
# numpy @ file:///tmp/build/80754af9/numpy_and_numpy_base_1596233718326/work
# nvidia-ml-py3==7.352.0
# opencensus==0.7.12
# opencensus-context==0.1.2
# opencv-python==4.5.1.48
# opencv-python-headless==4.3.0.36
# packaging==20.9
# pandas==1.1.5
# paramiko==2.7.2
# parso @ file:///tmp/build/80754af9/parso_1596826841367/work
# pathy==0.4.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.2.0
# preshed==3.0.5
# progress==1.5
# prometheus-client==0.9.0
# prompt-toolkit @ file:///tmp/build/80754af9/prompt-toolkit_1602688806899/work
# protobuf==3.15.1
# protobuf3-to-dict==0.1.5
# psutil==5.8.0
# ptyprocess==0.6.0
# py-spy==0.3.4
# pyarrow==3.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pybind11==2.6.2
# pycosat @ file:///home/conda/feedstock_root/build_artifacts/pycosat_1610094796351/work
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# pydantic==1.7.3
# pyfunctional==1.4.3
# pyglet==1.4.10
# Pygments @ file:///tmp/build/80754af9/pygments_1600458456400/work
# pyinstrument==3.4.1
# pyinstrument-cext==0.2.4
# PyNaCl==1.4.0
# PyOpenGL==3.1.0
# pyOpenSSL @ file:///tmp/build/80754af9/pyopenssl_1594392929924/work
# pyparsing==2.4.7
# pyrsistent==0.17.3
# PySocks @ file:///home/conda/feedstock_root/build_artifacts/pysocks_1610291458349/work
# python-dateutil @ file:///home/ktietz/src/ci/python-dateutil_1611928101742/work
# pytz @ file:///tmp/build/80754af9/pytz_1612215392582/work
# PyYAML==5.4.1
# pyzmq==22.0.3
# ray==1.1.0
# redis==3.5.3
# requests @ file:///tmp/build/80754af9/requests_1608241421344/work
# retrying==1.3.3
# rsa==4.7.1
# ruamel-yaml==0.15.87
# s3fs==0.4.2
# s3transfer==0.3.4
# sagemaker==2.25.1
# sagemaker-containers==2.8.6.post2
# sagemaker-experiments==0.1.28
# sagemaker-pytorch-training==2.4.0
# sagemaker-tensorflow-training==20.3.0
# sagemaker-training==3.7.3
# scikit-learn @ file:///tmp/build/80754af9/scikit-learn_1598379690588/work
# scipy==1.5.4
# setproctitle==1.2.2
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1590081179328/work
# sklearn==0.0
# smart-open==3.0.0
# smclarify==0.1
# smdebug==1.0.1
# smdebug-rulesconfig==1.0.1
# smdistributed-dataparallel @ https://smdataparallel.s3.amazonaws.com/binary/pytorch/1.7.1/cu110/2021-01-26/smdistributed_dataparallel-1.0.0-cp36-cp36m-linux_x86_64.whl
# smdistributed-modelparallel @ https://sagemaker-distributed-model-parallel.s3.amazonaws.com/pytorch-1.7/build-artifacts/2021-01-19-23-41/smdistributed_modelparallel-1.2.0-cp36-cp36m-linux_x86_64.whl
# soupsieve==2.2
# spacy==3.0.3
# spacy-legacy==3.0.1
# srsly==2.4.0
# tabulate==0.8.7
# tensorboardX==2.1
# tensorflow-probability==0.12.1
# tf-slim==1.1.0
# thinc==8.0.1
# threadpoolctl @ file:///tmp/tmp9twdgx9k/threadpoolctl-2.1.0-py3-none-any.whl
# torch @ https://aws-pytorch-binaries.s3-us-west-2.amazonaws.com/r1.7.1_aws/20210107-213753/df8e57a23cbc00d4fff51f4ea7f2ce052d1384e9/gpu/torch-1.7.1-cp36-cp36m-manylinux1_x86_64.whl
# torchfile==0.1.0
# torchnet==0.0.4
# torchvision @ https://torchvision-build.s3-us-west-2.amazonaws.com/1.7.1/gpu/torchvision-0.8.2%2Bcu110-cp36-cp36m-linux_x86_64.whl
# tornado==6.1
# tqdm @ file:///tmp/build/80754af9/tqdm_1605303662894/work
# traitlets==4.3.3
# typer==0.3.2
# typing==3.7.4.3
# typing-extensions==3.7.4.3
# urllib3 @ file:///tmp/build/80754af9/urllib3_1603305693037/work
# visdom==0.1.8.9
# wasabi==0.8.2
# wcwidth @ file:///tmp/build/80754af9/wcwidth_1593447189090/work
# websocket-client==0.57.0
# Werkzeug==1.0.1
# yarl==1.6.3
# zipp==3.4.0
# zope.event==4.5.0
# zope.interface==5.2.0
# Removing intermediate container 89163044f4f9
#  ---> 7cb7c577b971
# Step 23/24 : RUN python --version
#  ---> Running in 716ae6a2d089
# Python 3.6.13
# Removing intermediate container 716ae6a2d089
#  ---> 6515681cd33f
# Step 24/24 : RUN pip freeze | grep tensorflow
#  ---> Running in 6737738126e1
# sagemaker-tensorflow-training==20.3.0
# tensorflow-probability==0.12.1
# Removing intermediate container 6737738126e1
#  ---> b53734a73de0
# Successfully built b53734a73de0
# Successfully tagged ray-1_1_cartpole-gpu-torch-1.7.1:latest
# Done building docker image ray-1_1_cartpole-gpu-torch-1.7.1
# ECR repository already exists: ray-1_1_cartpole-gpu-torch-1.7.1
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Logged into ECR
# $ docker tag ray-1_1_cartpole-gpu-torch-1.7.1 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1
# Pushing docker image to ECR repository 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1
#
# $ docker push 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1
# The push refers to repository [775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1]
# b8fd8210c430: Preparing
# ef5d94753687: Preparing
# aacded0b1f96: Preparing
# f2a4daadc49d: Preparing
# 805c3bb7d17f: Preparing
# 36a3b3a8419d: Preparing
# 9b619bd058bb: Preparing
# 3bde80e67a26: Preparing
# 153b05085f81: Preparing
# c955c6d393e4: Preparing
# 09f0f23ca8d8: Preparing
# e0ca96f7997a: Preparing
# 39b8f1eb3341: Preparing
# 9f5e16025506: Preparing
# 8cadd9f2a4d3: Preparing
# f2d4502749ef: Preparing
# 7ca3b55a8274: Preparing
# bb9e13eae159: Preparing
# cc81312c5a27: Preparing
# 5a346f91a17c: Preparing
# 9b2be1f0f812: Preparing
# d0438729dd19: Preparing
# c198343a6132: Preparing
# 7905ebef1e78: Preparing
# fa617e36ccd6: Preparing
# 37cf71294c62: Preparing
# 8d09585879a4: Preparing
# af771a8733d4: Preparing
# a179757b4cf5: Preparing
# cb4e504eb567: Preparing
# f2ab6e8b4f50: Preparing
# a0c624d002ce: Preparing
# e8f67639cca3: Preparing
# 893e3836e0ce: Preparing
# 4f746328df4d: Preparing
# 626800c31be3: Preparing
# eca318b890fc: Preparing
# 03aea7c9e3d1: Preparing
# 53194dce1444: Preparing
# ef8330bcc944: Preparing
# 964ee116c0c0: Preparing
# 7a694df0ad6c: Preparing
# 3fd9df553184: Preparing
# 805802706667: Preparing
# e0ca96f7997a: Waiting
# 39b8f1eb3341: Waiting
# 9f5e16025506: Waiting
# 8cadd9f2a4d3: Waiting
# f2d4502749ef: Waiting
# 7ca3b55a8274: Waiting
# bb9e13eae159: Waiting
# cc81312c5a27: Waiting
# 5a346f91a17c: Waiting
# 9b2be1f0f812: Waiting
# d0438729dd19: Waiting
# c198343a6132: Waiting
# 7905ebef1e78: Waiting
# fa617e36ccd6: Waiting
# 37cf71294c62: Waiting
# 36a3b3a8419d: Waiting
# 9b619bd058bb: Waiting
# 3bde80e67a26: Waiting
# 153b05085f81: Waiting
# c955c6d393e4: Waiting
# 09f0f23ca8d8: Waiting
# 03aea7c9e3d1: Waiting
# 8d09585879a4: Waiting
# af771a8733d4: Waiting
# a179757b4cf5: Waiting
# cb4e504eb567: Waiting
# f2ab6e8b4f50: Waiting
# a0c624d002ce: Waiting
# e8f67639cca3: Waiting
# 893e3836e0ce: Waiting
# 4f746328df4d: Waiting
# 626800c31be3: Waiting
# eca318b890fc: Waiting
# 53194dce1444: Waiting
# ef8330bcc944: Waiting
# 964ee116c0c0: Waiting
# 7a694df0ad6c: Waiting
# 3fd9df553184: Waiting
# 805802706667: Waiting
# 805c3bb7d17f: Pushed
# 36a3b3a8419d: Layer already exists
# f2a4daadc49d: Pushed
# ef5d94753687: Pushed
# b8fd8210c430: Pushed
# aacded0b1f96: Pushed
# c955c6d393e4: Pushed
# e0ca96f7997a: Layer already exists
# 3bde80e67a26: Pushed
# 9f5e16025506: Layer already exists
# 39b8f1eb3341: Layer already exists
# 9b619bd058bb: Pushed
# f2d4502749ef: Layer already exists
# 8cadd9f2a4d3: Layer already exists
# 7ca3b55a8274: Layer already exists
# bb9e13eae159: Layer already exists
# cc81312c5a27: Layer already exists
# 9b2be1f0f812: Layer already exists
# 5a346f91a17c: Layer already exists
# d0438729dd19: Layer already exists
# c198343a6132: Layer already exists
# 7905ebef1e78: Layer already exists
# fa617e36ccd6: Layer already exists
# 8d09585879a4: Layer already exists
# 37cf71294c62: Layer already exists
# af771a8733d4: Layer already exists
# cb4e504eb567: Layer already exists
# a179757b4cf5: Layer already exists
# f2ab6e8b4f50: Layer already exists
# e8f67639cca3: Layer already exists
# a0c624d002ce: Layer already exists
# 893e3836e0ce: Layer already exists
# 4f746328df4d: Layer already exists
# 626800c31be3: Layer already exists
# eca318b890fc: Layer already exists
# 03aea7c9e3d1: Layer already exists
# 53194dce1444: Layer already exists
# ef8330bcc944: Layer already exists
# 964ee116c0c0: Layer already exists
# 7a694df0ad6c: Layer already exists
# 3fd9df553184: Layer already exists
# 805802706667: Layer already exists
# 09f0f23ca8d8: Pushed
# 153b05085f81: Pushed
# latest: digest: sha256:34defeb45c991be48aad3de67c47b1749fa2347b1dd5b7a027b8282692abe4fb size: 9556
# Done pushing 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1

# %% [markdown]
# Confirm the image name correctly refers to the version of Ray and tensorflow or torch libraries.

# %%
print("Using ECR image %s" % image_name)
# Out:
# Using ECR image 775004277940.dkr.ecr.us-west-2.amazonaws.com/ray-1_1_cartpole-gpu-torch-1.7.1

# %% [markdown]
# ### Metric Definitions

# %%
#metric_definitions = RLEstimator.default_metric_definitions(RLToolkit.RAY)

metric_definitions = [{'Name': 'episode_reward_mean',
  'Regex': 'episode_reward_mean: ([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?)'},
 {'Name': 'episode_reward_max',
  'Regex': 'episode_reward_max: ([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?)'},
 {'Name': 'episode_len_mean',
  'Regex': 'episode_len_mean: ([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?)'},
 {'Name': 'entropy',
  'Regex': 'entropy: ([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?)'},
 {'Name': 'episode_reward_min',
  'Regex': 'episode_reward_min: ([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?)'},                                           
]

# %% [markdown]
# ## Train the RL model using the Python SDK Script mode
#
# If you are using local mode, the training will run on the notebook instance. When using SageMaker for training, you can select a GPU or CPU instance. The RLEstimator is used for training RL jobs.
#
# 1. Specify the source directory where the environment, presets and training code is uploaded.
# 2. Specify the entry point as the training code
# 3. Specify the custom image to be used for the training environment.
# 4. Define the training parameters such as the instance count, job name, S3 path for output and job name.
# 5. Define the metrics definitions that you are interested in capturing in your logs. These can also be visualized in CloudWatch and SageMaker Notebooks.

# %% [markdown]
# Configure the number of training instances, note that this is different from the number of workers. Make sure the entry point is located in the source directory, i.e.`src` folder in this notebook. Set the training duration in seconds.

# %%
train_instance_count = 1
train_entry_point = "train-rl-cartpole-ray.py"
#train_entry_point = "train-rl-cartpole-ray-customEnv.py"

train_job_max_duration_in_seconds = 60 * 10

estimator = RLEstimator(entry_point= train_entry_point,
                        source_dir="src",
                        dependencies=["common/sagemaker_rl"],
                        image_uri=image_name,
                        role=role,
                        instance_type=instance_type,
                        instance_count=1,
                        output_path=s3_output_path,
                        base_job_name=job_name_prefix,
                        metric_definitions=metric_definitions,
                        max_run=train_job_max_duration_in_seconds,
                        debugger_hook_config=False,
                        hyperparameters={}
                       )

estimator.fit(wait=True)
job_name = estimator.latest_training_job.job_name
print("Training job: %s" % job_name)
# Out:
# 2021-03-10 05:18:58 Starting - Starting the training job...
# 2021-03-10 05:19:20 Starting - Launching requested ML instancesProfilerReport-1615353537: InProgress
# ......
# 2021-03-10 05:20:21 Starting - Preparing the instances for training......
# 2021-03-10 05:21:22 Downloading - Downloading input data...
# 2021-03-10 05:21:45 Training - Downloading the training image...........................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-03-10 05:26:16,572 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2021-03-10 05:26:16,596 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-03-10 05:26:18,006 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-03-10 05:26:18,223 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_estimator": "RLEstimator"
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "rl-cartpole-ray-2021-03-10-05-18-57-494",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-775004277940/rl-cartpole-ray-2021-03-10-05-18-57-494/source/sourcedir.tar.gz",
#     "module_name": "train-rl-cartpole-ray",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train-rl-cartpole-ray.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=train-rl-cartpole-ray.py
# SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train-rl-cartpole-ray
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-775004277940/rl-cartpole-ray-2021-03-10-05-18-57-494/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"rl-cartpole-ray-2021-03-10-05-18-57-494","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-775004277940/rl-cartpole-ray-2021-03-10-05-18-57-494/source/sourcedir.tar.gz","module_name":"train-rl-cartpole-ray","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train-rl-cartpole-ray.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 train-rl-cartpole-ray.py
#
#
# No checkpoint path specified. Training from scratch.
# Important! Ray with version <=0.7.2 may report "Did not find checkpoint file" even if the experiment is actually restored successfully. If restoration is expected, please check "training_iteration" in the experiment info to confirm.
# == Status ==
# Memory usage on this node: 2.8/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-------+
# | Trial name                  | status   | loc   |
# |-----------------------------+----------+-------|
# | PPO_CartPole-v1_27af5_00000 | RUNNING  |       |
# +-----------------------------+----------+-------+
#
#
# #033#033(pid=171)#033 [2021-03-10 05:26:28.338 algo-1:171 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=175)#033 [2021-03-10 05:26:28.343 algo-1:175 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=173)#033 [2021-03-10 05:26:28.353 algo-1:173 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=176)#033 [2021-03-10 05:26:28.389 algo-1:176 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=170)#033 [2021-03-10 05:26:28.413 algo-1:170 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=169)#033 [2021-03-10 05:26:28.441 algo-1:169 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=174)#033 [2021-03-10 05:26:28.596 algo-1:174 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=175)#033 [2021-03-10 05:26:28.638 algo-1:175 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=176)#033 [2021-03-10 05:26:28.754 algo-1:176 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=169)#033 [2021-03-10 05:26:28.750 algo-1:169 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=171)#033 [2021-03-10 05:26:28.758 algo-1:171 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=173)#033 [2021-03-10 05:26:28.772 algo-1:173 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=170)#033 [2021-03-10 05:26:28.795 algo-1:170 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=174)#033 [2021-03-10 05:26:28.856 algo-1:174 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=172)#033 [2021-03-10 05:26:32.425 algo-1:172 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=172)#033 [2021-03-10 05:26:32.634 algo-1:172 INFO profiler_config_parser.py:102] User has disabled profiler.
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
#
# 2021-03-10 05:26:47 Training - Training image download completed. Training in progress.Result for PPO_CartPole-v1_27af5_00000:
#   custom_metrics: {}
#   date: 2021-03-10_05-27-01
#   done: false
#   episode_len_mean: 22.316163410301954
#   episode_reward_max: 87.0
#   episode_reward_mean: 22.316163410301954
#   episode_reward_min: 8.0
#   episodes_this_iter: 1126
#   episodes_total: 1126
#   experiment_id: 36b1449aefd0486cb32d53b56ea67899
#   hostname: ip-10-0-205-215.us-west-2.compute.internal
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 1.0
#         cur_lr: 9.999999999999999e-05
#         entropy: 0.6786395219656137
#         entropy_coeff: 0.0
#         kl: 0.014588554067393908
#         policy_loss: -0.03246423984931495
#         total_loss: 85.2103024996244
#         vf_explained_var: 0.18003705143928528
#         vf_loss: 85.22817773085374
#     num_steps_sampled: 25200
#     num_steps_trained: 25200
#   iterations_since_restore: 1
#   node_ip: 10.0.205.215
#   num_healthy_workers: 7
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 52.240540540540536
#     gpu_util_percent0: 0.05837837837837837
#     ram_util_percent: 8.786486486486488
#     vram_util_percent0: 0.05806629649451433
#   pid: 172
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0764018821978134
#     mean_env_wait_ms: 0.4977890782979443
#     mean_inference_ms: 3.0913049965503303
#     mean_raw_obs_processing_ms: 0.19832423441821892
#   time_since_restore: 27.510882139205933
#   time_this_iter_s: 27.510882139205933
#   time_total_s: 27.510882139205933
#   timers:
#     learn_throughput: 2043.834
#     learn_time_ms: 12329.766
#     sample_throughput: 1662.605
#     sample_time_ms: 15156.934
#     update_time_ms: 3.98
#   timestamp: 1615354021
#   timesteps_since_restore: 0
#   timesteps_total: 25200
#   training_iteration: 1
#   trial_id: 27af5_00000
#
# == Status ==
# Memory usage on this node: 5.3/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc              |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | PPO_CartPole-v1_27af5_00000 | RUNNING  | 10.0.205.215:172 |      1 |          27.5109 | 25200 |  22.3162 |                   87 |                    8 |            22.3162 |
# +-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=170)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=175)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=169)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=173)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=174)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# Result for PPO_CartPole-v1_27af5_00000:
#   custom_metrics: {}
#   date: 2021-03-10_05-27-28
#   done: false
#   episode_len_mean: 38.18844984802432
#   episode_reward_max: 162.0
#   episode_reward_mean: 38.18844984802432
#   episode_reward_min: 9.0
#   episodes_this_iter: 658
#   episodes_total: 1784
#   experiment_id: 36b1449aefd0486cb32d53b56ea67899
#   hostname: ip-10-0-205-215.us-west-2.compute.internal
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 1.0
#         cur_lr: 9.999999999999999e-05
#         entropy: 0.639765556042011
#         entropy_coeff: 0.0
#         kl: 0.013269517785654618
#         policy_loss: -0.028957954204927843
#         total_loss: 210.66495396540716
#         vf_explained_var: 0.18878181278705597
#         vf_loss: 210.68064762995795
#     num_steps_sampled: 50400
#     num_steps_trained: 50400
#   iterations_since_restore: 2
#   node_ip: 10.0.205.215
#   num_healthy_workers: 7
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 53.88857142857143
#     gpu_util_percent0: 0.05742857142857143
#     ram_util_percent: 8.800000000000002
#     vram_util_percent0: 0.058601485148514855
#   pid: 172
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0782106452513902
#     mean_env_wait_ms: 0.31993082809140216
#     mean_inference_ms: 3.1893865530151495
#     mean_raw_obs_processing_ms: 0.170518400038587
#   time_since_restore: 54.27876257896423
#   time_this_iter_s: 26.7678804397583
#   time_total_s: 54.27876257896423
#   timers:
#     learn_throughput: 2046.639
#     learn_time_ms: 12312.869
#     sample_throughput: 1702.227
#     sample_time_ms: 14804.139
#     update_time_ms: 3.926
#   timestamp: 1615354048
#   timesteps_since_restore: 0
#   timesteps_total: 50400
#   training_iteration: 2
#   trial_id: 27af5_00000
#
# == Status ==
# Memory usage on this node: 5.3/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc              |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | PPO_CartPole-v1_27af5_00000 | RUNNING  | 10.0.205.215:172 |      2 |          54.2788 | 50400 |  38.1884 |                  162 |                    9 |            38.1884 |
# +-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_CartPole-v1_27af5_00000:
#   custom_metrics: {}
#   date: 2021-03-10_05-27-53
#   done: false
#   episode_len_mean: 80.97402597402598
#   episode_reward_max: 284.0
#   episode_reward_mean: 80.97402597402598
#   episode_reward_min: 10.0
#   episodes_this_iter: 308
#   episodes_total: 2092
#   experiment_id: 36b1449aefd0486cb32d53b56ea67899
#   hostname: ip-10-0-205-215.us-west-2.compute.internal
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 1.0
#         cur_lr: 9.999999999999999e-05
#         entropy: 0.6095888156157273
#         entropy_coeff: 0.0
#         kl: 0.0072203431672488265
#         policy_loss: -0.015609080670401454
#         total_loss: 434.8726560152494
#         vf_explained_var: 0.1650252491235733
#         vf_loss: 434.88103661170373
#     num_steps_sampled: 75600
#     num_steps_trained: 75600
#   iterations_since_restore: 3
#   node_ip: 10.0.205.215
#   num_healthy_workers: 7
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 50.88529411764706
#     gpu_util_percent0: 0.05970588235294117
#     ram_util_percent: 8.8
#     vram_util_percent0: 0.05860148514851485
#   pid: 172
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07693679878983946
#     mean_env_wait_ms: 0.2508701607318796
#     mean_inference_ms: 3.15328132490503
#     mean_raw_obs_processing_ms: 0.1510563110436821
#   time_since_restore: 79.81322431564331
#   time_this_iter_s: 25.534461736679077
#   time_total_s: 79.81322431564331
#   timers:
#     learn_throughput: 2047.379
#     learn_time_ms: 12308.42
#     sample_throughput: 1765.203
#     sample_time_ms: 14275.978
#     update_time_ms: 3.953
#   timestamp: 1615354073
#   timesteps_since_restore: 0
#   timesteps_total: 75600
#   training_iteration: 3
#   trial_id: 27af5_00000
#
# == Status ==
# Memory usage on this node: 5.3/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc              |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | PPO_CartPole-v1_27af5_00000 | RUNNING  | 10.0.205.215:172 |      3 |          79.8132 | 75600 |   80.974 |                  284 |                   10 |             80.974 |
# +-----------------------------+----------+------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_CartPole-v1_27af5_00000:
#   custom_metrics: {}
#   date: 2021-03-10_05-28-19
#   done: false
#   episode_len_mean: 136.95027624309392
#   episode_reward_max: 337.0
#   episode_reward_mean: 136.95027624309392
#   episode_reward_min: 15.0
#   episodes_this_iter: 181
#   episodes_total: 2273
#   experiment_id: 36b1449aefd0486cb32d53b56ea67899
#   hostname: ip-10-0-205-215.us-west-2.compute.internal
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 1.0
#         cur_lr: 9.999999999999999e-05
#         entropy: 0.5863135640437787
#         entropy_coeff: 0.0
#         kl: 0.004297533869528427
#         policy_loss: -0.014114356151996897
#         total_loss: 458.87608102651745
#         vf_explained_var: 0.26062873005867004
#         vf_loss: 458.88589360163763
#     num_steps_sampled: 100800
#     num_steps_trained: 100800
#   iterations_since_restore: 4
#   node_ip: 10.0.205.215
#   num_healthy_workers: 7
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 53.19117647058823
#     gpu_util_percent0: 0.05941176470588235
#     ram_util_percent: 8.8
#     vram_util_percent0: 0.05860148514851485
#   pid: 172
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07675580002309962
#     mean_env_wait_ms: 0.21662644963363067
#     mean_inference_ms: 3.1581013103427282
#     mean_raw_obs_processing_ms: 0.14099677610637884
#   time_since_restore: 105.58129334449768
#   time_this_iter_s: 25.76806902885437
#   time_total_s: 105.58129334449768
#   timers:
#     learn_throughput: 2047.011
#     learn_time_ms: 12310.633
#     sample_throughput: 1791.533
#     sample_time_ms: 14066.165
#     update_time_ms: 3.855
#   timestamp: 1615354099
#   timesteps_since_restore: 0
#   timesteps_total: 100800
#   training_iteration: 4
#   trial_id: 27af5_00000
#
# == Status ==
# Memory usage on this node: 5.3/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc              |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_CartPole-v1_27af5_00000 | RUNNING  | 10.0.205.215:172 |      4 |          105.581 | 100800 |   136.95 |                  337 |                   15 |             136.95 |
# +-----------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# #033#033(pid=171)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# #033#033(pid=176)#033 #033ERROR: VideoRecorder encoder exited with status 1#033
# Result for PPO_CartPole-v1_27af5_00000:
#   custom_metrics: {}
#   date: 2021-03-10_05-28-45
#   done: true
#   episode_len_mean: 212.94017094017093
#   episode_reward_max: 495.0
#   episode_reward_mean: 212.94017094017093
#   episode_reward_min: 12.0
#   episodes_this_iter: 117
#   episodes_total: 2390
#   experiment_id: 36b1449aefd0486cb32d53b56ea67899
#   hostname: ip-10-0-205-215.us-west-2.compute.internal
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.5
#         cur_lr: 9.999999999999999e-05
#         entropy: 0.5729340062691615
#         entropy_coeff: 0.0
#         kl: 0.005573720366765673
#         policy_loss: -0.011355024314700412
#         total_loss: 418.320067185622
#         vf_explained_var: 0.4684045910835266
#         vf_loss: 418.3286261925331
#     num_steps_sampled: 126000
#     num_steps_trained: 126000
#   iterations_since_restore: 5
#   node_ip: 10.0.205.215
#   num_healthy_workers: 7
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 50.25428571428571
#     gpu_util_percent0: 0.060571428571428575
#     ram_util_percent: 8.800000000000002
#     vram_util_percent0: 0.058601485148514855
#   pid: 172
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0761995199328591
#     mean_env_wait_ms: 0.20323361080766414
#     mean_inference_ms: 3.1446094426434317
#     mean_raw_obs_processing_ms: 0.13492146533528585
#   time_since_restore: 131.78390955924988
#   time_this_iter_s: 26.202616214752197
#   time_total_s: 131.78390955924988
#   timers:
#     learn_throughput: 2046.016
#     learn_time_ms: 12316.622
#     sample_throughput: 1797.18
#     sample_time_ms: 14021.971
#     update_time_ms: 3.949
#   timestamp: 1615354125
#   timesteps_since_restore: 0
#   timesteps_total: 126000
#   training_iteration: 5
#   trial_id: 27af5_00000
#
# == Status ==
# Memory usage on this node: 5.3/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 8/8 CPUs, 1/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc              |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_CartPole-v1_27af5_00000 | RUNNING  | 10.0.205.215:172 |      5 |          131.784 | 126000 |   212.94 |                  495 |                   12 |             212.94 |
# +-----------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 5.3/60.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/33.64 GiB heap, 0.0/11.57 GiB objects (0/1.0 accelerator_type:V100)
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1/1 (1 TERMINATED)
# +-----------------------------+------------+-------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status     | loc   |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+------------+-------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_CartPole-v1_27af5_00000 | TERMINATED |       |      5 |          131.784 | 126000 |   212.94 |                  495 |                   12 |             212.94 |
# +-----------------------------+------------+-------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Saved model configuration.
#
# 2021-03-10 05:29:01 Uploading - Uploading generated training modelSaved the checkpoint file /opt/ml/output/intermediate/training/PPO_CartPole-v1_27af5_00000_0_2021-03-10_05-26-24/checkpoint_5/checkpoint-5 as /opt/ml/model/checkpoint
# Saved the checkpoint file /opt/ml/output/intermediate/training/PPO_CartPole-v1_27af5_00000_0_2021-03-10_05-26-24/checkpoint_5/checkpoint-5.tune_metadata as /opt/ml/model/checkpoint.tune_metadata
# Loaded config for TensorFlow serving.
# #033#033(pid=931)#033 [2021-03-10 05:28:53.018 algo-1:931 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# #033#033(pid=931)#033 [2021-03-10 05:28:53.226 algo-1:931 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-03-10 05:28:54.882 algo-1:71 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-03-10 05:28:54.948 algo-1:71 INFO profiler_config_parser.py:102] User has disabled profiler.
# 2021-03-10 05:26:22,485#011INFO services.py:1173 -- View the Ray dashboard at #033#033http://127.0.0.1:8265#033#033
# #033#033(pid=172)#033 2021-03-10 05:26:25,762#011INFO trainer.py:618 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=174)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=174)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=175)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=175)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=171)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=171)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=170)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=170)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=169)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=169)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=173)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=173)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=176)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=176)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=176)#033 2021-03-10 05:26:34,849#011WARNING deprecation.py:30 -- DeprecationWarning: `env_index` has been deprecated. Use `episode.env_id` instead. This will raise an error in the future!
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# 2021-03-10 05:28:46,101#011INFO tune.py:448 -- Total run time: 141.85 seconds (141.40 seconds for the tuning loop).
# 2021-03-10 05:28:51,141#011INFO trainer.py:618 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=931)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=931)#033   tensor = torch.from_numpy(np.asarray(item))
# 2021-03-10 05:28:55,428#011INFO trainable.py:329 -- Restored on 10.0.205.215 from checkpoint: /opt/ml/model/checkpoint
# 2021-03-10 05:28:55,429#011INFO trainable.py:336 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 131.78390955924988, '_episodes_total': 2390}
# Traceback (most recent call last):
#   File "train-rl-cartpole-ray.py", line 48, in <module>
#     MyLauncher().train_main()
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 350, in train_main
#     launcher.launch()
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 343, in launch
#     use_pytorch=use_pytorch)
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 251, in save_checkpoint_and_serving_model
#     self.create_tf_serving_model(algorithm, env_string)
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 243, in create_tf_serving_model
#     export_tf_serving(agent, MODEL_OUTPUT_DIR)
#   File "/opt/ml/code/sagemaker_rl/tf_serving_utils.py", line 29, in export_tf_serving
#     agent.export_policy_model(os.path.join(output_dir, "1"))
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 976, in export_policy_model
#     self.workers.local_worker().export_policy_model(export_dir, policy_id)
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1001, in export_policy_model
#     self.policy_map[policy_id].export_model(export_dir)
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/policy/torch_policy.py", line 574, in export_model
#     raise NotImplementedError
# NotImplementedError
#
# 2021-03-10 05:28:58,533 sagemaker-containers ERROR    Reporting training FAILURE
# 2021-03-10 05:28:58,533 sagemaker-containers ERROR    framework error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_containers/_trainer.py", line 84, in train
#     entrypoint()
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_pytorch_container/training.py", line 121, in main
#     train(environment.Environment())
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_pytorch_container/training.py", line 80, in train
#     six.reraise(info[0], err, info[2])
#   File "/opt/conda/lib/python3.6/site-packages/six.py", line 703, in reraise
#     raise value
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_pytorch_container/training.py", line 73, in train
#     runner_type=runner_type)
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_training/entry_point.py", line 100, in run
#     wait, capture_error
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_training/process.py", line 164, in run
#     cwd=environment.code_dir,
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_training/process.py", line 84, in check_error
#     raise error_class(return_code=return_code, cmd=" ".join(cmd), output=stderr)
# sagemaker_training.errors.ExecuteUserScriptError: ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 train-rl-cartpole-ray.py"
# 2021-03-10 05:26:22,485#011INFO services.py:1173 -- View the Ray dashboard at #033#033http://127.0.0.1:8265#033#033
# #033#033(pid=172)#033 2021-03-10 05:26:25,762#011INFO trainer.py:618 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=174)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=174)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=175)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=175)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=171)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=171)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=170)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=170)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=169)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=169)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=173)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=173)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=176)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=176)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=176)#033 2021-03-10 05:26:34,849#011WARNING deprecation.py:30 -- DeprecationWarning: `env_index` has been deprecated. Use `episode.env_id` instead. This will raise an error in the future!
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# 2021-03-10 05:28:46,101#011INFO tune.py:448 -- Total run time: 141.85 seconds (141.40 seconds for the tuning loop).
# 2021-03-10 05:28:51,141#011INFO trainer.py:618 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=931)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=931)#033   tensor = torch.from_numpy(np.asarray(item))
# 2021-03-10 05:28:55,428#011INFO trainable.py:329 -- Restored on 10.0.205.215 from checkpoint: /opt/ml/model/checkpoint
# 2021-03-10 05:28:55,429#011INFO trainable.py:336 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 131.78390955924988, '_episodes_total': 2390}
# Traceback (most recent call last):
#   File "train-rl-cartpole-ray.py", line 48, in <module>
#     MyLauncher().train_main()
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 350, in train_main
#     launcher.launch()
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 343, in launch
#     use_pytorch=use_pytorch)
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 251, in save_checkpoint_and_serving_model
#     self.create_tf_serving_model(algorithm, env_string)
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 243, in create_tf_serving_model
#     export_tf_serving(agent, MODEL_OUTPUT_DIR)
#   File "/opt/ml/code/sagemaker_rl/tf_serving_utils.py", line 29, in export_tf_serving
#     agent.export_policy_model(os.path.join(output_dir, "1"))
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 976, in export_policy_model
#     self.workers.local_worker().export_policy_model(export_dir, policy_id)
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1001, in export_policy_model
#     self.policy_map[policy_id].export_model(export_dir)
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/policy/torch_policy.py", line 574, in export_model
#     raise NotImplementedError
# NotImplementedError
#
# ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 train-rl-cartpole-ray.py"
# 2021-03-10 05:26:22,485#011INFO services.py:1173 -- View the Ray dashboard at #033#033http://127.0.0.1:8265#033#033
# #033#033(pid=172)#033 2021-03-10 05:26:25,762#011INFO trainer.py:618 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=174)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=174)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=175)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=175)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=171)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=171)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=170)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=170)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=169)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=169)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=173)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=173)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=176)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=176)#033   tensor = torch.from_numpy(np.asarray(item))
# #033#033(pid=176)#033 2021-03-10 05:26:34,849#011WARNING deprecation.py:30 -- DeprecationWarning: `env_index` has been deprecated. Use `episode.env_id` instead. This will raise an error in the future!
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=170)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# #033#033(pid=175)#033 Unknown encoder 'libx264'
# #033#033(pid=169)#033 Unknown encoder 'libx264'
# #033#033(pid=173)#033 Unknown encoder 'libx264'
# #033#033(pid=174)#033 Unknown encoder 'libx264'
# #033#033(pid=171)#033 Unknown encoder 'libx264'
# #033#033(pid=176)#033 Unknown encoder 'libx264'
# 2021-03-10 05:28:46,101#011INFO tune.py:448 -- Total run time: 141.85 seconds (141.40 seconds for the tuning loop).
# 2021-03-10 05:28:51,141#011INFO trainer.py:618 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=931)#033 /opt/conda/lib/python3.6/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:141.)
# #033#033(pid=931)#033   tensor = torch.from_numpy(np.asarray(item))
# 2021-03-10 05:28:55,428#011INFO trainable.py:329 -- Restored on 10.0.205.215 from checkpoint: /opt/ml/model/checkpoint
# 2021-03-10 05:28:55,429#011INFO trainable.py:336 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 131.78390955924988, '_episodes_total': 2390}
# Traceback (most recent call last):
#   File "train-rl-cartpole-ray.py", line 48, in <module>
#     MyLauncher().train_main()
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 350, in train_main
#     launcher.launch()
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 343, in launch
#     use_pytorch=use_pytorch)
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 251, in save_checkpoint_and_serving_model
#     self.create_tf_serving_model(algorithm, env_string)
#   File "/opt/ml/code/sagemaker_rl/ray_launcher.py", line 243, in create_tf_serving_model
#     export_tf_serving(agent, MODEL_OUTPUT_DIR)
#   File "/opt/ml/code/sagemaker_rl/tf_serving_utils.py", line 29, in export_tf_serving
#     agent.export_policy_model(os.path.join(output_dir, "1"))
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 976, in export_policy_model
#     self.workers.local_worker().export_policy_model(export_dir, policy_id)
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1001, in export_policy_model
#     self.policy_map[policy_id].export_model(export_dir)
#   File "/opt/conda/lib/python3.6/site-packages/ray/rllib/policy/torch_policy.py", line 574, in export_model
#     raise NotImplementedError
# NotImplementedError
#
# 2021-03-10 05:29:30 Failed - Training job failed
# ProfilerReport-1615353537: Stopping
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-15-c0e72699af25> in <module>
#      20                        )
#      21
# ---> 22 estimator.fit(wait=True)
#      23 job_name = estimator.latest_training_job.job_name
#      24 print("Training job: %s" % job_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     659         self.jobs.append(self.latest_training_job)
#     660         if wait:
# --> 661             self.latest_training_job.wait(logs=logs)
#     662
#     663     def _compilation_job_name(self):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1586         # If logs are requested, call logs_for_jobs.
#    1587         if logs != "None":
# -> 1588             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1589         else:
#    1590             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3638
#    3639         if wait:
# -> 3640             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3641             if dot:
#    3642                 print()
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3220                 ),
#    3221                 allowed_statuses=["Completed", "Stopped"],
# -> 3222                 actual_status=status,
#    3223             )
#    3224
#
# UnexpectedStatusException: Error for Training job rl-cartpole-ray-2021-03-10-05-18-57-494: Failed. Reason: AlgorithmError: framework error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_containers/_trainer.py", line 84, in train
#     entrypoint()
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_pytorch_container/training.py", line 121, in main
#     train(environment.Environment())
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_pytorch_container/training.py", line 80, in train
#     six.reraise(info[0], err, info[2])
#   File "/opt/conda/lib/python3.6/site-packages/six.py", line 703, in reraise
#     raise value
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_pytorch_container/training.py", line 73, in train
#     runner_type=runner_type)
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_training/entry_point.py", line 100, in run
#     wait, capture_error
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_training/process.py", line 164, in run
#     cwd=environment.code_dir,
#   File "/opt/conda/lib/python3.6/site-packages/sagemaker_training/pro

# %% [markdown]
# ## Visualization
#
# RL training can take a long time.  So while it's running there are a variety of ways we can track progress of the running training job.  Some intermediate output gets saved to S3 during training, so we'll set up to capture that.

# %%
print("Job name: {}".format(job_name))

s3_url = "s3://{}/{}".format(s3_bucket,job_name)

intermediate_folder_key = "{}/output/intermediate/".format(job_name)
intermediate_url = "s3://{}/{}".format(s3_bucket, intermediate_folder_key)

print("S3 job path: {}".format(s3_url))
print("Intermediate folder path: {}".format(intermediate_url))
    
tmp_dir = "/tmp/{}".format(job_name)
os.system("mkdir {}".format(tmp_dir))
print("Create local folder {}".format(tmp_dir))

# %% [markdown]
# ### Fetch videos of training rollouts
# Videos of certain rollouts get written to S3 during training.  Here we fetch the last 10 videos from S3, and render the last one.

# %%
recent_videos = wait_for_s3_object(
            s3_bucket, intermediate_folder_key, tmp_dir, 
            fetch_only=(lambda obj: obj.key.endswith(".mp4") and obj.size>0), 
            limit=10, training_job_name=job_name)

# %%
last_video = sorted(recent_videos)[-1]  # Pick which video to watch
os.system("mkdir -p ./src/tmp_render/ && cp {} ./src/tmp_render/last_video.mp4".format(last_video))
HTML('<video src="./src/tmp_render/last_video.mp4" controls autoplay></video>')

# %% [markdown]
# ### Plot metrics for training job
# We can see the reward metric of the training as it's running, using algorithm metrics that are recorded in CloudWatch metrics.  We can plot this to see the performance of the model over time.

# %%
# %matplotlib inline
from sagemaker.analytics import TrainingJobAnalytics

if not local_mode:
    df = TrainingJobAnalytics(job_name, ['episode_reward_mean']).dataframe()
    num_metrics = len(df)
    if num_metrics == 0:
        print("No algorithm metrics found in CloudWatch")
    else:
        plt = df.plot(x='timestamp', y='value', figsize=(12,5), legend=True, style='b-')
        plt.set_ylabel('Mean reward per episode')
        plt.set_xlabel('Training time (s)')
else:
    print("Can't plot metrics in local mode.")

# %% [markdown]
# ### Monitor training progress
# You can repeatedly run the visualization cells to get the latest videos or see the latest metrics as the training job proceeds.

# %% [markdown]
# ## Evaluation of RL models
#
# We use the last checkpointed model to run evaluation for the RL Agent.
#
# ### Load checkpointed model
#
# Checkpointed data from the previously trained models will be passed on for evaluation / inference in the checkpoint channel. In local mode, we can simply use the local directory, whereas in the SageMaker mode, it needs to be moved to S3 first.

# %%
if local_mode:
    model_tar_key = "{}/model.tar.gz".format(job_name)
else:
    model_tar_key = "{}/output/model.tar.gz".format(job_name)
    
local_checkpoint_dir = "{}/model".format(tmp_dir)

wait_for_s3_object(s3_bucket, model_tar_key, tmp_dir, training_job_name=job_name)  

if not os.path.isfile("{}/model.tar.gz".format(tmp_dir)):
    raise FileNotFoundError("File model.tar.gz not found")
    
os.system("mkdir -p {}".format(local_checkpoint_dir))
os.system("tar -xvzf {}/model.tar.gz -C {}".format(tmp_dir, local_checkpoint_dir))

print("Checkpoint directory {}".format(local_checkpoint_dir))

# %%
if local_mode:
    checkpoint_path = 'file://{}'.format(local_checkpoint_dir)
    print("Local checkpoint file path: {}".format(local_checkpoint_dir))
else:
    checkpoint_path = "s3://{}/{}/checkpoint/".format(s3_bucket, job_name)
    if not os.listdir(local_checkpoint_dir):
        raise FileNotFoundError("Checkpoint files not found under the path")
    os.system("aws s3 cp --recursive {} {}".format(local_checkpoint_dir, checkpoint_path))
    print("S3 checkpoint file path: {}".format(checkpoint_path))

# %%
# %%time
    
estimator_eval = RLEstimator(entry_point="evaluate-ray.py",
                        source_dir='src',
                        dependencies=["common/sagemaker_rl"],
                        image_uri=image_name,
                        role=role,
                        instance_type=instance_type,
                        instance_count=1,
                        base_job_name=job_name_prefix + "-evaluation",
                        hyperparameters={
                            "evaluate_episodes": 10,
                            "algorithm": "PPO",
                            "env": "CartPole-v1"
                        }
                    )

estimator_eval.fit({'model': checkpoint_path})
job_name = estimator_eval.latest_training_job.job_name
print("Evaluation job: %s" % job_name)

# %% [markdown]
# # Model deployment
#
# Now let us deploy the RL policy so that we can get the optimal action, given an environment observation.
#
# **Note**: Model deployment is supported for TensorFLow only at current stage.
#
# STOP HERE IF PYTORCH IS USED.

# %%
from sagemaker.tensorflow.model import TensorFlowModel

model = TensorFlowModel(model_data=estimator.model_data,
              framework_version='2.3.1',
              role=role)

predictor = model.deploy(initial_instance_count=1, 
                         instance_type=instance_type)

# %%
# ray 0.8.5 requires all the following inputs
# 'prev_action', 'is_training', 'prev_reward' and 'seq_lens' are placeholders for this example
# they won't affect prediction results

# Number of different values stored in at any time in the current state for the Cartpole example.
CARTPOLE_STATE_VALUES = 4

input = {"inputs": {'observations': np.ones(shape=(1, CARTPOLE_STATE_VALUES)).tolist(),
                    'prev_action': [0, 0],
                    'is_training': False,
                    'prev_reward': -1,
                    'seq_lens': -1
                   }
        }

# %%
print(input)

# %%
result = predictor.predict(input)

#result['outputs']['actions_0']

# %% [markdown]
# ### Clean up endpoint

# %%
predictor.delete_endpoint()
